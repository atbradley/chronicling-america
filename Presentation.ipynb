# %% [markdown]
# # Introduction
#
# ## Current Projects and Ongoing Work:
#
# * Rails: Upgrading RIAMCO ([Rhode Island Archival and Manuscript Collections Online](https://www.riamco.org/)) to a newer version of Rails. Was previously a series of PHP scripts and XSLT Templates.
# * Python for Natural Language Processing: A current project with the Center for Digital Scholarship to analyze Twitter data to measure attitudes toward racial disparities in maternal health in the context of COVID-19.
# * PHP: Brown's Online Course Reserves Application.
#
# ## Other Technical skills
#
# * Python
#     * Web programming (Django, Bottle, Wagtail)
#     * Visualization (matplotlib, Seaborn)
# * Jupyter - sketching, presentations, notetaking, discussion.
# * Databases (SQL, Solr)
# * JavaScript (D3, jQuery)
# * Git (collaboration, deployment)

# %%
#I need a few imports.
from collections import Counter, namedtuple
from difflib import HtmlDiff
import io
from math import ceil
from operator import itemgetter
import re
from tempfile import NamedTemporaryFile
from time import sleep
from urllib.parse import urlencode
from xml.etree import ElementTree as ET

import nltk
from nltk.corpus import brown, stopwords
from nltk.stem.snowball import SnowballStemmer
from PIL import Image
from pydash import py_
import pytesseract
import spacy
from rake_nltk import Rake
from requests import get, post
from textblob import TextBlob
import textract

import bingsc_settings as sc

from IPython import display

# %% [markdown]
# # Querying _Chronicling America_
#
# This is a simple REST API. I just use the Python `requests` package to query it.

# %%
#URL template for searching Chronicling America.
searchtemplate = '''https://chroniclingamerica.loc.gov/search/pages/results/\
# ?state=&x=0&y=0&dateFilterType=yearRange&rows={count}&searchType=basic\
&format=json&language=eng\
&date1={startDate}&date2={endDate}&proxtext={searchTerms}&page={page}'''
searchopts = re.findall('\{(.+?)\}', searchtemplate)
searchopts

srch = {
    'searchTerms': 'mackenzie king', 
    'startDate': 1941, 
    'endDate': 1942,
    'count': 10,
}
searchterms = {x: srch.get(x, '') for x in searchopts}
searchterms

papersearch = get(searchtemplate.format(**searchterms)).json()
len(papersearch)
# Out:
# 5

# %% [markdown]
# I'm looking at [page 30 of the October 26, 1941 _Sunday Star_](https://chroniclingamerica.loc.gov/lccn/sn83045462/1941-10-26/ed-1/seq-30/#date1=1941&index=7&rows=100&words=King+Mackenzie&searchType=basic&sequence=0&state=&date2=1945&proxtext=mackenzie+king&y=0&x=0&dateFilterType=yearRange&page=1).

# %%
i = papersearch['items'][1]
i
# Out:
# {'sequence': 30,
#  'county': [None],
#  'edition': None,
#  'frequency': 'Daily',
#  'id': '/lccn/sn83045462/1941-10-26/ed-1/seq-30/',
#  'subject': ['Washington (D.C.)--fast--(OCoLC)fst01204505',
#   'Washington (D.C.)--Newspapers.'],
#  'city': ['Washington'],
#  'date': '19411026',
#  'title': 'Evening star. [volume]',
#  'end_year': 1972,
#  'note': ['"From April 25 through May 24, 1861 one sheet issues were published intermittently owing to scarcity of paper." Cf. Library of Congress, Photoduplication Service.',
#   'Also issued on microfilm from Microfilming Corp. of America and the Library of Congress, Photoduplication Service.',
#   'Archived issues are available in digital format as part of the Library of Congress Chronicling America online collection.',
#   'Publisher varies: Noyes, Baker & Co., <1867>; Evening Star Newspaper Co., <1868->',
#   "Suspended Jan. 1-6, 1971 because of a machinists' strike."],
#  'state': ['District of Columbia'],
#  'section_label': '',
#  'type': 'page',
#  'place_of_publication': 'Washington, D.C.',
#  'start_year': 1854,
#  'edition_label': '',
#  'publisher': 'W.D. Wallach & Hope',
#  'language': ['English'],
#  'alt_title': ['Star', 'Sunday star'],
#  'lccn': 'sn83045462',
#  'country': 'District of Columbia',
#  'ocr_eng': '“ss;- - pje pumky Pte ■\' °“N,ws b\n* TEX PAGES. WASHINGTON, D. C., OCTOBER 26, 1941.\n—-----—-—---r--- — n :\nWar With U. S. Seen Inevitable\nIf Tokio Plays for Big Stakes\nLittle Opposition Likely in Congress to Settling\nScores With Japan if Nipponese Push\nPlan to Attack Siberia\nBy Constantine Broivn.\nAdministrative quarters in Washing\nton and most members of Congress\nincluding some of the inveterate isola\ntionists—are reported to share Navy\nSecretary Knox’s belief that war between\nthe United States and Japan is almost\nInevitable.\nIf the Moscow front collapses, the per\nsonal position of Joseph Stalin may be\nin jeopardy. Dictators cannot survive\ndefeats. The political situation in the\nU. S. S. R. is open to unlimited conjec\nture.\nThe Japanese have now assumed the\nrole that the Italians ployed in 1910\nafter the fall of France. With the de\nfeat of the principal Soviet armies gen\nerally conceded. Tokio is reported plan\nning to strike at Siberia. The Germans\nare encouraging them in this action.\nNazi agents and diplomats have been\nextremely active in Japan ever since the\nbeginning of American-Japanese nego\ntiations for an amicable settlement of\nthe Pacific problem. As long as the\nGerman armies encountered fierce oppo\nsition in Russia they knew that the\nnervous Japanese would listen to the\nBritish and American diplomats who\nwere telling them that the Nazis would\nnot get through to Moscow and would\nfail to _ pulverize the Soviet fighting\nforces. Hence. Japan was willing to dis\ncuss terms with the United States.\nThese terms were not particularly favor\nable to Japan and would have been dis\nastrous for the Reich if Tokio had ac\n“Wait and See" Policy Urged.\nThe paramount condition for settle\nment of the Pacific question was Japan\'s\nabandonment of the Axis. Following\nthe advice of the German diplomats and\nmoney disbursing agents, the Japanese\nagreed to "wait and see.” That was all\nthe Reich wanted of them for the time\nbeing. The German Ambassador, who\nconferred frequently with Prince Premier\nFumimaro Konoye and who was re\nceived at least twice by the Emperor\nhimself, is reported to have told them\nthat Russia was being slowly defeated.\nThe Nazi envoy also is reported "to have\nraid that the Reich did not want Japan\nto do anything either with or against the\nUnited States until she was satisfied with\nthe trend of events, and that after the\nRussians had been defeated the Emperor\nhad better follow the poliay which he\ndeemed most advantageous for the em\npire and the dynasty. But until defeat\nof Russia was assured. Hitler’s envoy\nbegged the Emperor to mark time and do\nnothing which might compromise the\nplans of the Axis.\nThis. Emperor Hirohito and his cabinet\ndid. For weeks the Japanese refrained\nfrom any warlike activity. They did not\neven attempt to intercept the few tankers\nend cargo boats which the United States\ngent to Vladivostok. Informal discus\nsions were going on between Washington\nand Tokio. They were slow and dilatory.\nBargaining for Big Stakes.\nThe Tokio foreign minister explained\nto the often impatient Ambassador\nJoseph C. Grew that the imperial gov\nernment had to consider the hotheads\nIn the army and navy. Hence, he ex\nplained, the conversations would have\nto continue for a long time and could\nrot reach definite shape until the mili\ntary clique was muzzled. The United\nStates thought this delay could do no\nharm. We had taken precautionary\nmeasures in the Far East and the ad\nministration was not worried over any\ngurprises.\nThere is no doubt that the imperial\ngovernment itself looked with favor at\nthe possibility of an understanding with\n11_TT.iUJ nn cteinnr\nwere attached to Japan\'s expansion on\nthe Asiatic mainland. For nearly 10\nweeks the Japanese went on bargaining\nfor big stakes. The collapse of the active\nRussian front was occurring with greater\nrapidity than Tokio expected. It-more\nthan confirmed the German content ...
#  'batch': 'dlc_1tatlin_ver01',
#  'title_normal': 'evening star.',
#  'url': 'https://chroniclingamerica.loc.gov/lccn/sn83045462/1941-10-26/ed-1/seq-30.json',
#  'place': ['District of Columbia--Washington'],
#  'page': ''}

# %%
text = i['ocr_eng']

# %% [markdown]
# # Bing Spell Check
#
# I'm using a spell checker to try to correct OCR errors. My first try was with the [`PySpellchecker` module](https://pyspellchecker.readthedocs.io/en/latest/index.html), but this focuses on a single word at a time and wasn't particularly useful here. [Microsoft's Spell Check API](https://azure.microsoft.com/en-us/services/cognitive-services/spell-check/) looks at context and does a better job.
#
# Most of the complexity in my `bing_spellcheck` function involves keeping queries within Bing's 10,000-character per-request limit. I divide the text into sentences using `NLTK` and send groups of sentences to Bing. I also remove characters other than letters, numbers and some punctuation, since some characters seem to confuse the API.

# %%
scparams = {
    'mkt':'en-us',
    'mode':'proof'
}
scheaders = {
    'Content-Type': 'application/x-www-form-urlencoded',
    'Ocp-Apim-Subscription-Key': sc.KEY1,
    #'X-Search-Location': 'lat:41.823611;long:-71.422222;re:2000'
}

SC_MAX_LENGTH = 10000


def bing_spellcheck(text):
    """
    Send `text` to the Bing Spell Check API, breaking it into
    chunks if necessary to stay below the maximum input length of 
    10000 bytes.
    
    Returns corrected text and the raw response from Bing.
    """
    #Many (most? all?) of these documents seem to contain 
    #some characters that breaks the spell checker. 
    #This regex replaces anything but letters, numbers, 
    #and common punctuation with spaces.
    text = re.sub(r'[^a-zA-Z0-9\.\?!,"\';:\- ]+', ' ', text)
    sentences = nltk.sent_tokenize(text)
    bit_length = ceil(len(sentences) / (ceil(len(text) / SC_MAX_LENGTH)))
    sctext = ''
    scoutp = []
    
    while len(sentences) > 0:
        bit = False
        mult = 1.1
        diff = 0
        
        #find a small enough group of sentences to send to the API.
        while len(sentences) > 0:
            bit = False
            mult = 1.1
            diff = 0
            while (bit is False or len(bit) > SC_MAX_LENGTH) and mult > .1:
                mult -= .1
                scount = ceil(bit_length*mult)
                bit = ' '.join(sentences[:scount])         
                scbit = ' '.join(sentences[:scount])
            del(sentences[:scount])

            data = {
                'text': bit
            }
            rsp = post(sc.ENDPOINT, headers=scheaders, params=scparams, data=data)
            scdata = rsp.json()

            #Go through the suggested replacements and create a fixed copy of the text.
            for repl in scdata.get('flaggedTokens', []):
                start = repl['offset'] - diff
                token = repl['token']
                end = start + len(token)

                sug = repl['suggestions'][0].get('suggestion', token)

                #print('token:', token, 'suggestion:', sug)
                #print(scbit[start-100:start], '----', scbit[start:end], '----', scbit[end:end+100])
                scbit = scbit[:start] + sug + scbit[end:]
                diff += len(token) - len(sug)

            sctext += scbit
            scoutp.append(scdata)
            
    return (sctext, scoutp)

sctext, _ = bing_spellcheck(text)

# %% [markdown]
# Using `diff`, we can evaluate the changes made by the spellchecker.

# %%
hd = HtmlDiff()
tbl = hd.make_table(nltk.word_tokenize(text), nltk.word_tokenize(sctext), 
                    fromdesc='text', todesc='sctext', context=True, numlines=2)
display.HTML(tbl)
# Out:
#     <table class="diff" id="difflib_chg_to0__top"
#            cellspacing="0" cellpadding="0" rules="groups" >
#         <colgroup></colgroup> <colgroup></colgroup> <colgroup></colgroup>
#         <colgroup></colgroup> <colgroup></colgroup> <colgroup></colgroup>
#         <thead><tr><th class="diff_next"><br /></th><th colspan="2" class="diff_header">text</th><th class="diff_next"><br /></th><th colspan="2" class="diff_header">sctext</th></tr></thead>
#         <tbody>
#             <tr><td class="diff_next" id="difflib_chg_to0__0"><a href="#difflib_chg_to0__1">n</a></td><td class="diff_header" id="from0_1">1</td><td nowrap="nowrap"><span class="diff_sub">“</span></td><td class="diff_next"><a href="#difflib_chg_to0__1">n</a></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_2">2</td><td nowrap="nowrap">ss</td><td class="diff_next"></td><td class="diff_header" id="to0_1">1</td><td nowrap="nowrap">ss</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_3">3</td><td nowrap="nowrap">;</td><td class="diff_next"></td><td class="diff_header" id="to0_2">2</td><td nowrap="nowrap">;</td></tr>
#         </tbody>
#         <tbody>
#             <tr><td class="diff_next" id="difflib_chg_to0__1"></td><td class="diff_header" id="from0_7">7</td><td nowrap="nowrap">pumky</td><td class="diff_next"></td><td class="diff_header" id="to0_6">6</td><td nowrap="nowrap">pumky</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_8">8</td><td nowrap="nowrap">Pte</td><td class="diff_next"></td><td class="diff_header" id="to0_7">7</td><td nowrap="nowrap">Pte</td></tr>
#             <tr><td class="diff_next" id="difflib_chg_to0__2"><a href="#difflib_chg_to0__2">n</a></td><td class="diff_header" id="from0_9">9</td><td nowrap="nowrap"><span class="diff_sub">■</span></td><td class="diff_next"><a href="#difflib_chg_to0__2">n</a></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_10">10</td><td nowrap="nowrap">'</td><td class="diff_next"></td><td class="diff_header" id="to0_8">8</td><td nowrap="nowrap">'</td></tr>
#             <tr><td class="diff_next"><a href="#difflib_chg_to0__3">n</a></td><td class="diff_header" id="from0_11">11</td><td nowrap="nowrap"><span class="diff_sub">°</span></td><td class="diff_next"><a href="#difflib_chg_to0__3">n</a></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_12">12</td><td nowrap="nowrap"><span class="diff_sub">“</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_13">13</td><td nowrap="nowrap">N</td><td class="diff_next"></td><td class="diff_header" id="to0_9">9</td><td nowrap="nowrap">N</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_14">14</td><td nowrap="nowrap">,</td><td class="diff_next"></td><td class="diff_header" id="to0_10">10</td><td nowrap="nowrap">,</td></tr>
#             <tr><td class="diff_next" id="difflib_chg_to0__3"></td><td class="diff_header" id="from0_15">15</td><td nowrap="nowrap">ws</td><td class="diff_next"></td><td class="diff_header" id="to0_11">11</td><td nowrap="nowrap">ws</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_16">16</td><td nowrap="nowrap">b</td><td class="diff_next"></td><td class="diff_header" id="to0_12">12</td><td nowrap="nowrap">b</td></tr>
#             <tr><td class="diff_next"><a href="#difflib_chg_to0__4">n</a></td><td class="diff_header" id="from0_17">17</td><td nowrap="nowrap"><span class="diff_sub">*</span></td><td class="diff_next"><a href="#difflib_chg_to0__4">n</a></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_18">18</td><td nowrap="nowrap">TEX</td><td class="diff_next"></td><td class="diff_header" id="to0_13">13</td><td nowrap="nowrap">TEX</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_19">19</td><td nowrap="nowrap">PAGES</td><td class="diff_next"></td><td class="diff_header" id="to0_14">14</td><td nowrap="nowrap">PAGES</td></tr>
#         </tbody>
#         <tbody>
#             <tr><td class="diff_next" id="difflib_chg_to0__4"></td><td class="diff_header" id="from0_29">29</td><td nowrap="nowrap">1941</td><td class="diff_next"></td><td class="diff_header" id="to0_24">24</td><td nowrap="nowrap">1941</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_30">30</td><td nowrap="nowrap">.</td><td class="diff_next"></td><td class="diff_header" id="to0_25">25</td><td nowrap="nowrap">.</td></tr>
#             <tr><td class="diff_next"><a href="#difflib_chg_to0__5">n</a></td><td class="diff_header" id="from0_31">31</td><td nowrap="nowrap"><span class="diff_sub">—</span></td><td class="diff_next"><a href="#difflib_chg_to0__5">n</a></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next" id="difflib_chg_to0__5"></td><td class="diff_header" id="from0_32">32</td><td nowrap="nowrap">--</td><td class="diff_next"></td><td class="diff_header" id="to0_26">26</td><td nowrap="nowrap">--</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_33">33</td><td nowrap="nowrap">--</td><td class="diff_next"></td><td class="diff_header" id="to0_27">27</td><td nowrap="nowrap">--</td></tr>
#             <tr><td class="diff_next"><a href="#difflib_chg_to0__6">n</a></td><td class="diff_header" id="from0_34">34</td><td nowrap="nowrap"><span class="diff_sub">-—-—</span></td><td class="diff_next"><a href="#difflib_chg_to0__6">n</a></td><td class="diff_header" id="to0_28">28</td><td nowrap="nowrap"><span class="diff_add">-</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td><td class="diff_next"></td><td class="diff_header" id="to0_29">29</td><td nowrap="nowrap"><span class="diff_add">-</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_35">35</td><td nowrap="nowrap">--</td><td class="diff_next"></td><td class="diff_header" id="to0_30">30</td><td nowrap="nowrap">--</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_36">36</td><td nowrap="nowrap">-r</td><td class="diff_next"></td><td class="diff_header" id="to0_31">31</td><td nowrap="nowrap">-r</td></tr>
#             <tr><td class="diff_next" id="difflib_chg_to0__6"></td><td class="diff_header" id="from0_37">37</td><td nowrap="nowrap">--</td><td class="diff_next"></td><td class="diff_header" id="to0_32">32</td><td nowrap="nowrap">--</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_38">38</td><td nowrap="nowrap">-</td><td class="diff_next"></td><td class="diff_header" id="to0_33">33</td><td nowrap="nowrap">-</td></tr>
#             <tr><td class="diff_next"><a href="#difflib_chg_to0__7">n</a></td><td class="diff_header" id="from0_39">39</td><td nowrap="nowrap"><span class="diff_sub">—</span></td><td class="diff_next"><a href="#difflib_chg_to0__7">n</a></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_40">40</td><td nowrap="nowrap">n</td><td class="diff_next"></td><td class="diff_header" id="to0_34">34</td><td nowrap="nowrap">n</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_41">41</td><td nowrap="nowrap">:</td><td class="diff_next"></td><td class="diff_header" id="to0_35">35</td><td nowrap="nowrap">:</td></tr>
#         </tbody>
#         <tbody>
#             <tr><td class="diff_next" id="difflib_chg_to0__7"></td><td c

# %% [markdown]
# # Tesseract OCR

# %% [markdown]
# I experimented with re-OCR'ing the scanned images. The process is slow, and I wasn't impressed with the results.

# %%
pagedata = get(i['url']).json()
pageimg = get(pagedata['jp2']).content

# %%
imgdata = io.BytesIO()
imgdata.write(pageimg)
imgdata.seek(0)

img = Image.open(imgdata)
img.format = 'TIFF'

# %%
tesscfg = r'--oem 3 --psm 3'
newtext = pytesseract.image_to_string(img, config=tesscfg)

# %%
print(newtext)
# Out:
# Editorial Page
# Features
#
# .
#
# The Sumiay Star
#
# Civics
#
# Organization News
#
#
#
# TEN PAGES.
#
#
#
# War With U. S. Seen Inevitable
#
# If Tokio Plays for Big Stakes
#
# Little Opposition Likely in Congress to Settling
#
# Scores With Japan if Nipponese Push — -
# Plan to Attack Siberia
#
# By Constantine Brown.
#
# Administrative quarters in Washing-
# ton and most members of Congress—
# including some of the inveterate isola-
# tionists—are reported
# Secretary Knox’s belief’'that war between
# the United States and Japan is almost
# inevitable.
#
# If the Moscow front collapses, the per-
# sonal position of Joseph Stalin may be
# in jeopardy. Dictators cannot survive
#
# defeats.
# U. S. S. R. is open to unlimited ccnjec-
# ture.
#
# The Japanese have now assumed the
# role that the Italians pleyed in 1949
# after the fall of France. With the de-
# feat of the principal Soviet armies gen-
# erally conceded, Tokio is reported pian-
# ning to strike at Siberia. The Germans
# are encouraging them in this action.
#
# Nazi agents and diplomats have been
# extremely active in Japan ever since the
# beginning of American-Japanese nego-
# tiations for an amicable settlement of
# the Pacific problem. As long as the
# German armies encountered fierce oppo-
# sition in Russia they knew that the
# nervous Japanese would listen to the
# British and American diplomats who
# were telling them that the Nazis would
# not get through to Moscow. and would
# fail to pulverize the Soviet fighting
# forces. Hence, Japan was willing to dis-
# cuss* terms. with the United States.
# These terms were not particularly favor-
# able to Japan and would have been dis-
# astrous for the Reich if Tokio had ac-
# cepted them.
#
# “Wait and See” Policy Urged.
#
# The paramount condition for settle-
# ment of the Pacific question was Japan's
# abandonment of the Axis. Following
#
# ]
#
# |
#
# to share Navy |
#
# States for a status quo in the Pacific
# were useless.
#
# Like all Orientals, the Japanese’ did
# not say this in so many words. There
#
# | was a good deal of circumlocution and
#
# The political situation in the |
#
# | would necessarily
#
# protestation of friendship for America.
# But they gave the United States Gov-
# ernment to understand that reasons of
# self-defense would compel Japan to
# attack Siberia. These reasons are phari-
# saic but are not so considered by the
# Japanese rulers.
#
# Russia. they sey, has coliansed. There
# wil te hundreds of thousands, if not
# millions, of Communist so’diers sceling
# refuce in Siberia after the Cefect ef
# €talin’s armies in Evrove. The Asiatic
# pertion of the U. S. ©. R. would rrovide
# theso ~defeated troops with an ical
# haven. These men would ke armed,
# there are many raw materials in that
# vast area and it wouldn't be long before
# new arms factories would be erected
# there.
#
# Hence the Siberian armies would be
# fully equipped in a few years and com-
# pletely independent of the rest of Russia
# eas far as industrial production is con-
# cerned. The millions would draw other
# millions who would want to flee either
# the Germans or the new regime which
# be established in
#
# | Russia.
#
# These men, say the Japanese, wouldn’t
# find Siberia sufficient and would en-
# deavor to spread southward. All terri-
#
# | tory south of Siberia is of vital concern
#
# | to the Japanese.
#
# }
# '
#
# | and China.
#
# There is Manchukuo,
# for example, which exists under the pro-
# tecting wing of the Nipponese Empire.
# Soon or late, observers say, there will be
# a conflict between the expanding Rus-
# sians and the “protectors” of Manchukuo
# If much time is wasted this
#
# | conflict might become dangerous for
#
# the advice of the German diplomats and |
# money disbursing agents, the Japanese |
#
# agreed to “wait and see.” That was all
#
# the Reich wanted of them for the time |
#
# being. The German Ambassador. who
# conferred frequently with Prince Premier
# Fumimaro Konoye and who was re-
# ceived at least twice by the Emperor
# himself, is reported to have told them
# that Russia was being slowly defeated.
#
# The Nazi envoy also is reported to have
#
# Japan.
# Determined to Settle Question.
#
# Furthermore, the Japanese say, they
# hope that a period of peace and hap-
# piness’ will follow the present turmoil.
# It would be fatal for future generations
#
# WASHINGTON,
#
# Blueprint of Aggression
#
# Two Heavy Books Present Hitler’s Creed
#
#
#
# ITLER’S bluevrint for world domi-
# nation is spread out for all to see in
# two heavy volumes of ‘more than 1,000
# pages each, now published in English
# by Reynald and Hitchcock. The first
# is the unexvourgated “Mein Kampf,”
# written by Hitler in 1924 and 1926; the
# second is “My New Order,” a compila-
# tion of his speeches edited by the
# French journalist Raoul de Roussy de
# Sales. The last named, a sequel to
# “Mein Kampf,” brings the Hitlerian rec-
# ord up to the proclamation of’ June 22
# announcing the invasion of Soviet
# Russia. :
# Valuable additions to this book are a
# background chronology of world events
#
# | affecting Germany from Hitler's first
#
# | of copies have been sold.
#
# | —who will have to work to mend the ;
# | appealed successfully to the despondent
#
# gaid that the Reich did not want Japan |
#
# to do anything either with or against the | date Siberia as quickly as possible.
#
# United States until she was satisfied with
#
# the trend of events, and that after the |
# Russians had been defeated the Emperor |
# had better follow the poliey which he |
#
# deemed most advantageous for the em-
# pire and the dynasty. But until defeat
#
# of Russia was assured, Hitler’s envoy: | brought under the “protection” of ‘the
#
# begged the Emperor to mark time and do
# nothing which might compromise the
# plans of the Axis.
#
# This, Emperor Hirohito and his cabinet
# did. For weeks the Japanese refrained
#
# scars caused by the present world war—
#
# to have to worry about the potential |
#
# menace from the north. Hence, for the
# sake of law and order, Tokio contends,
# the Japanese will be compelled to liqui-
#
# Furthermore, they add, in order to put
# an end to the Communist menace in
# Asia (a continent which the Japanese
# rulers
# ground of the yellow races represented
# by the Javanese), Siberia must be
#
# ‘ Nipponese Empire.
#
# from any warlike activity. They cid not |
#
# even attempt to intercept the few tankers
# and cargo boats which the United States
# sent to Vladivostok. Informal discus-
# sions were going on between Washington
# and Tokio. They were slow and dilatory.
# Bargaining for Big Stakes.
#
# The Tokio foreign minister explained
# to the often impatient Ambassador
# Joseph C. Grew that the imperial gov-
# ernment had to consider the hotheads
# {n the army and navy.
#
# Hence, he ex- |
#
# plained, the conversations would have |
#
# to continue for a long time and could
# not reach definite shape until the mili-
# tary clique was muzzled. The United
# States thought this delay could do no
# harm. We had taken precautionary
# measures in the Far East and the ad-
# ministration was not worried over any
# surprises.
#
# There is no doubt that the imperial
# government itself looked with favor at
# the possibility of an understanding with
# the United States—provided no strings
# were attached to Japan’s expansion on
# the Asiatic mainland. For nearly 10
# weeks the Japanese went on bargaining
# Yor big stakes. The collapse of the active
#
# Russian front was occurring with greater
# yapidity than Tokio expected. It- more
# than confirmed the German contention
# that Russia was at the mercy of the
# Reich any time Hitler decided that the
# moment had come to sacrifice a million
# men.
#
# The vast German offensive appealed
# to the Nipponese. It appeared to them
# as somewhat of a mass harakiri at the
# altar of the fatherland. No sooner did
# 4t become apparent that the Russians
# were through on the western front than
# the Tokio cabinet decided that any
# further negotiations with the United
#
# There is, of course, a possibility, say
# the Japanese, that some direct “arrange-
# ments” could be made with the Russian
# generel commandihg in Siberia. But
# that would not be satisfactory, since
# Japan does not wish a vestige of Aryen
# authority to be left anywhere near China.
# It is consequently necessary, Tokio adds,
# that the Siberian question, which has
#
# been boiling since 1905, should be settled
#
# at this time to the satisfaction of the | to no rank, who stands above all that. I
#
# have nothing but the ties which bind me |
#
# yellow races once and for all.
#
# ‘Why, ask the Japanese, in their be-
# guiling manner, should America get ex-
# cited over this? Surely the American
# people have no idea of taking Siberia for
# themselves. Why risk a costly war for
# the sake of Russian colonists in Asiatic
#
# | territory?
#
# (cn tm sia SSeS eens
#
# U. S. Assistance Pledged.
#
# The answer that will be given to the
# Tokio government will be revealed as
# soon as the White House decides on the
# course of action to be taken if the Jap-
# anese forces cross the Manchukuo-
# Siberian border.
#
# But there are strong indications that
# this country will not remain an im-
# passive spectator in the new conflict
# which is believed likely to break out
# within the next three weess in the Far
# East.
#
# The United States has pledged itself
# to assist any nation which opposes Axis
# domination by force of arms. Whether
# the Muscovite government collapses or
# not is immaterial as far as the policies
# of this government are concerned. As
# soon as the Soviet army in Siberia is
# attacked by the Japanese—the official
# allies of Hitler—we are honor bound to
# assist Stalin's armies regardless of
# whether he continues as the head of
# the Soviet government or not.
#
# The administration has stated re-
#
#
#
# (Continued on Page B-3, ‘Column 3.)
#
# nT
#
#
#
# Lookin’ for Trouble, Buddy? —By Jack Lambert.
#
# d
#
# |
#
# imvortant speech in Munich in April,
# 12922, to date: M. de Sales’ comments on
# the principal phases of the National
# Sociaist program, and editorial observ-
# etions in London, Paris and New York
# on mervy cf the public addresses.
#
# The importance of these Historical
# documents to contemporary
#
# life can |
#
# hardly be exaggerated. They are basic |
#
# source material. “Mein Kampf” is the
# Bible of the Third Reich, where millions
# In this coun-
# try, although hundreds of thousands of
# the books have been bought, it is doubt-
# ful whether they have been read as
# deeply as they deserve. Had they been
# studied by -the political and editorial
# leaders of England, France, Russia and
# the Balkans, the present war might have
# been averted. It is not too late for
# Americans to inform themselves about
# Hitler's ambitions, in large part already
# realized.
# Reveals Effective Technique.
#
# Study of these books is: not easy. De-
# tails are often conflicting; Hitler's fair
# promises mask unscrupulous deeds, but
# throughout runs the definite theme that
# the Germans are a superior race, des-
# tined to dominate the world if they will
#
# submit to the visionary but relentless |
#
# leadership of the unknown corporal of
# the World War.
#
# In these books Hitler reveals himself
# as the consummate politician, the arch
# demagogue, the effective compromiser
# who knows how to await his time.
#
# one must marvel at his effective po-
# litical technique.
#
# Hitler worked out a- formula which
#
# the support of the industrialists, who
# thought they could do business with
# him, just as Huey Long was successfully
# appealing
#
# but not too far, in his shakedown of
#
# consider the exclusive hunting | >USinessmen. Both men were given their
#
# opportunity by the economic depression.
#
# Believers in Carlyle’s thesis of na-
# tional heroes as well as believers in the
# Marxian doctrine of economic determin-
# ism will find support for their hiStorical
# concepts in Hitler's words. The man
# who began as a soap-box orator built
# himself up into a national hero, the per-
# sonification of the Germanic soul. When
# he was calling for German unity he said:
#
# “Iam the guarantor in Germany that
# this community shall not result in the
#
# does not belong to any class, who belongs
#
# to the German people. Here for me every
# German is on a complete equality. What
#
# interest have I in the intellectuals, in the |
#
# bourgeoisie. in the proletariat? I am in-
# terested only in the German people. To
# the people alone I belong and for the
# people I spend my energies.”
#
# Require Digestive Reading.
#
# This would support the Carlylist view-
# point. But the Marxian historians can
# point to a speech three years later, when
# Hitler was scrapping the treaties, in
# which he declared:
#
# “The opinion that European order can
# be founded permanently on the defama-
# tion of a people numbering 67,000,000 is
# Tunatic and madness. They do not need
# to think that the German nation has
# rebelled simply because a certain man,
# Adolf Hitler, stands at its head. No, if
# I were not here another would have
# come sooner or later.”
#
# The two books are too ponderous and
# diffuse for adequate summary in a re-
# view of this type and they are not rec-
# ommended to the casual reader who
# hops, skips and jumps at a hundred
# pages an hour. The full stature of the
# German leader and the devious working
# of his mind can be comprehended only
# by a study of the man’s own words and
# the background against which they
# were uttered. Francis Hackett has at-
# tempted a condensation of “Mein
# Kampf” in his work “What Mein Kampf
# Means to America,” but the American
# citizen who wants to know why Germany
# submitted to a self-styled dictator and
# how the Hitlerian technique could be
# applied to this country can find the most
# understandable answer in the emotional
# propaganda of the man who built the
# infinitesimal German Workers’ Party
# into a machine for world conquest. No
# other man has appealed so effectively to
# the masses and at the same time de-
# ceived the so-called intelligentsia. :
#
# : Weapons in Words.
#
# In a foreword to “My New Order,” M.
# de Sales points out:
#
# “Hitler’s speeches are weapons, as
# much a part of his strategy of conquest
# as more direct instruments of warfare.
# Hitler is past master of throwing up
# verbal smoke screens to conceal his in-
# tended moves. He knows equally well the
# effectiveness of massive oratorical as-
# saults that shake the nerves of his vic-
# tims or opponents and break down their
# resistance. He knows how to give pledges
# that will be broken later, but will serve
# temporarily to divide and confuse, and
# to create the illusion of security. He
# uses insults and lies in the same manner
# as his generals use Stuka planes and
# tanks to break through the respectable
# but often weak front of his adversaries.
# He contradicts himself constantly but
# his contradictions often produce the
# effects of a psychological pincer-move-
# ment whieh crushes the best defense of
# logic and ordinary morality.”
#
# D. C., OCTOBER
#
# By Raymond P. Brandt
#
#
#
# ADOLF HITLER.
#
# “Some part of the most impu-
# dent lie will remain and stick—-a
# fact which all great lying artists
# and societies of this world know
#
# only too well and_ therefore
# also villainously employ.’—‘Mein
# Kampf.” —A. P. Photo.
#
# Political technique or popular appeal
#
# | has several fundamental principles ap-
#
# | plicable to all countries.
#
# | Whatever one may think of his goals, |
#
# to the underprivileged by |
#
# promising to make “every man a king,” | _,; =
# and at the same time was able to go far, | ee a
#
# Hitler had
#
# | ligious nature sliding was, from the be-
#
# 26, 1941,
#
# although he laid great emphasis on his
# own newspaper, Volkischer Beobachter,
# and he glorified the spoken word, saying:
#
# “The power which set the greatest
# historical avalanches of political and re-
#
# ginning of time, the magic force of the
#
# | spoken word alone.
#
# “The great masses of a nation will
# always and only succumb to the force of
# the spoken word. But all great move-
# ments are movements of the people, are
# volcanic eruptions of human passions
# ahd spiritual sensations, stirred either
# by the cruel Goddess of Misery or by
# the torch of the word thrown into the
# masses, and are not the lemonade-like
#
# After Hitler attained power he was
# not concerned about the pronerty rights
#
# of the industrialists, as Fritz Thyssen |
#
# and others learned to their sorrow.
# Speaking in Nuremberg in September,
# 1933, he told the party members:
#
# “No one has a moral right to demand
# that others should work for him so that
# he will not have to work himself. Each
# has a right to demand that the political
# organization of his nation, the state,
# find ways and means to give work to all.”
#
# “Mein Kampf” gives Hitler’s plans for
# a@ reorganized Germany that will last for
# a thousand years—a period for which he
# has a special fondness—while “My New
# Order” shows how he is trying to carry
# out these grandiose ideas. “Mein
#
# | Kampf” is the foundation, “My New
#
# Order” is the superstructure.
# Unworried by Critics.
#
# Criticism meant little to Hitler. In
# fact, he turned it to his own advantage
#
# | by attacking those who criticized him.
#
# “In my eyes,” he told a Hamburg
#
# | audience in 1934, “criticism in itself is
#
# many natural and fortuitous advantages. |
#
# He came from a poor Austrian family,
# shared the lot of the lowest laborers and
# served as a corporal throughout the
# World War. Without formal education,
# he knew people. He worked out what
# seemed at the time to be a fantastic long-
# range program for which he declared
#
# German working classes and later gained | ee ee
#
# his followers. German discontent made
# him.
#
# For post-war Germany, his formula
# was sure-fire if he could only get mo-
# mentum behind it. The depression sup-
# In brief his
# formula was:.
#
# Find fault with all existing conditions:
# promise everything to everybody; make
# the Germans believe they should rule the
# world and that Hitler alone should rule
# Germany.
#
# Wide Range of Discontent.
#
# In detail, he attacked the treaty of
# Versailles, the Weimer Republic, the par-
# liamentary system, trade unionism, the
# Social Democratic and Communist par-
#
# , ties, the governmental bureaucracy, the
#
# houses of Hapsburg and Hohenzollern,
#
# Soviet Russia, France, the international
# favoring of ome section of our people.
#
# You can look upon me as the man who |
#
#
#
#
#
#
#
#
#
# bankers and especially the Jews.
#
# not an important function in life. The
# world can live without critics, it cannot
# live without workmen. I protest against
# the notion that there should exist a
# profession whose sole reason for its ex-
# istence is that its professors, without
# personal responsibility, should of their
# superior wisdom continually interrupt
#
# ' those who are working and who carry
#
# responsibilities. In my own life I have
# fought for 14 years against a govern-
# ment, but not with negative criticism,
# but always pointing to that which
# should be done. I have accepted re-
# sponsibility when it was offered me.
#
# ; And no action will be taken by me which
#
# He promised to fulfill all wishes and |
#
# hopes, telling the peasants they would
#
# get land and the Junkers they would lose
#
# no property. He pledged higher wages to
#
# the workers and promised employers that |
#
# wage costs would be reduced.
# He criticized all other Germans ex-
#
# | cept Frederick the Great, Wagner and
#
# Von Hindenberg. Bismarck was almost
# but not quite one of his heroes.
# The two books supplement each other
#
# ® ted references to Jews.
#
# in showing how he rose to power in the |
#
# National Socialist party; how that party
# under his leadership got control of the
# Reichstag and finally the government:
# how he unified the political, economic
# and social life of Germany, and how he
# set out to dominate Europe and the
# world. =
#
# Criticisms and promises, however, have
# been the politician’s stock-in-trade from
# time immemorial. Hitler improved on
# two practices used by his enemies, the
# Communists. He developed Storm Troop-
# ers, who gave the Nazis “control of the
# streets” against the Socialists and Com-
# munists, and he established a system of
# hierarchic party “cells,” with the leader
# of each “cell” solely responsible to his
# immediate superior for the actions of its
# members. The Storm Troopers protected
# the Nazi mass meetings and broke up
# ose of their opponents. They demanded
# free speech for themselves while denying
# it to others. The autocratic leadership
# of the “cells” eliminated all democratic
# solutions of party problems.
#
# Caught Fancy of Youth.
#
# In addition, perhaps the reason for
# his most permanent, successes, he ob-
# tained the support of the German youth,
# the “lost” generation of the post-war
# period, which had become despondent
# and reckless from unemployment and
# lack of opportunity.
#
# No politician, unless it was Huey Long,
# has been so brutally frank with his
# prospective followers as Hitler is in
# “Mein Kampf.” He used the democratic
# processes of free speech, free assembly,
# free press and free elections to gain
# power, but he announced that once he
# attained leadership, he would be guided
# only by his own conscience. He realized
# that he had to have the support of the
# masses to win election, saying: “Every
# movement with great aims has anxiously
# to watch that it may not lose connection
# with the great masses.”
#
# Hitler, then without responsibility,
# was willing to take responsibility. “Bed
# bug parliamentarians,” he declared, hid
# behind the coattails of the majority on
# all important questions. The “leader,” he
# said, must be willing to risk his head for
# the carrying out of ruthless decision. He
# added: ‘
#
# “One thing we must and may never
# forget: Here, too, a majority can never
# replace the man. It ‘is not only always a
# representative of stupidity, but also of
# cowardice. Just as a hundred fools do
# not make one wise man, an heroic deci-
# sion is not likely to come from a hun-
# dred cowards.”
#
# He was also contemptuous of writers,
#
# b
#
# I am not prepared to defend before this
# people with my head and with my life.”
#
# Hitler scorned what he called the
# “scientific intelligentsia” and told his
# lieutenants they must appeal “forever
# and only to the masses.” Vereatility, he
# declaréd, was all wrong. i
#
# “The great masses’ receptive ability
# is only very limited, their understanding
# is small, but their forgetfulness is
# great. As a consequence of these facts,
# all effective propaganda has to limit
# itself to a very few points and to use
# them like slogans until the very last
# man is able to imagine what is intended
# by such a word. As soom as one sacri-
# fices this basic principle and tries to
# become versatile, the effect will fritter
# away, as the masses are neither able
# to digest the material offered or to re-
# tain it. Thus the result is weakened
# and finally eliminated.”
#
# An Opportunist.
#
# But the up-and-coming politician
# knew when to compromise. “My New
# Order” contains the text of his talk to
# a private meeting of the Industry Club
# of Duesseldorf in January, 1932, in
#
# | which Hitler appealed for support of
#
# big business. This speech. was replete
# with sycophantic “gentlemen” and omit-
# Hitler knew his
# audience, and compared his demand for
# political leadership with the actual sit-
# uation in industry. He told the employ-
#
# | ing group:
#
# cmathieu tht TE CCE EES Se CEE ECE ee A a
# schanaeshestessitistlaiigpeiiaineas
#
# “It is absurd to build up economic
# life on the conceptions of achievement,
# of the value of personality, and there-
# fore in practice on the authority of per-
# sonality, but in the political sphere to
# deny the authority of personality and
# to thrust into its place the law of the
# greater number— democracy.”
#
# In other words, he was promising a
# “businessman's government.”
#
# The German businessmen, he knew,
# feared Communism, and well they might,
# because Berlin and other industrial cities
# had elected large numbers of Com-
# munists to their city councils. On this
# point Hitler told the industrialists:
#
# “How is a people to count for anything
# abroad when in the last resort 50 per
# cent are inclined to Bolshevism and 50
# per cent are Nationalists, or anti-Bol-
# shevists. It is quite conceivable to turn
# Germany into a Bolshevist state—it
# would be catastrophic, but it is conceiv-
# able. It is also conceivable to build up
# Germany as a national state. But it is
# inconceivable that one should create a
# strong and sound Germany if 50 per cent
# of its citizens are Bolshevists and 50 per
# cent nationally-minded. From the so-
# lution of this. proklem we _ cannot
# escape!”
#
# A Gangster Plus.
#
# It is impossible here even to enumerate
# the many contradictions of word and
# deed, the deliberate falsifications, the
# temporary shifting of policies. David
# Cushman Coyle, the pamphleteer, in his
# best-selling bookiet “America,” compares
# Hitler, his Storm Troopers and his Ges-
# tapo to our own racketeering gangsters.
# This perhaps is over-simplification, al-
# though the methods of gaining and using
# power are almost identical, as the read-
# ing of Hitler’s words will show. Ameri-
# cans cannot be supercilious and say,
# “It can’t happen here.” Huey Long
# would be an extremely dangerous man
# were he alive today.
#
# As late as 1933 it was customary for
# non-Germens to laugh at Hitler because
# of his Charlie Chaplin mustache and
# to recall that he had been a house
# painter and a paper hanger. A con-
# densed version of “Mein Kampf” even
# then was available in English. If it had
# been studied, Britain and America would
# have been better prepared for one of
# the greatest surprises in all history.
#
# The newspaper comment included in
# M. De Sales’ compilation is a reminder
#
# (See BRANDT, Page B-3.)
#
# .
#
# l
#
# outpouring of estheticizing literati and |
# | drawing room heroes.”
#
# Canada’s ‘Guns-or-Butter’ Step
#
# Regarded as Portent for U. S.
#
# Two Nations Differ, But Nevertheless the Moral
# Is Nazis Can’t Be Beaten Under
#
# ; ‘Business as Usual’
# By Felix Morley.
#
# From Ottawa Mr. Mackenzie King has
# broadcast to his people a warning that
# Canada, like Germany before it, must
# now choose Letween guns and butter.
#
# The Canadian Prime Minister’s repe-
# tition of Marshal Goering’s once much-
# derided phrase falls like a shadow of
# coming events across the border between
# the Dominion and the United States. If
# theré is need in Canada for the au-
#
# thoritarian measures scheduled to take |
#
# effect November 15, the probability of
# their eventual adoption here is strong.
#
# Indeed, in some respects there seems
# less urgency in Canada than in the
#
# | United States for the drastic steps in
# price and wage control which Mr. Mace |
#
# kenzie King envisages. Since the out-
#
# | break of war the price level in Canada
#
# | and agricultural
#
# ‘trols which Mr.
#
# has been surprisingly stable. There
# have been relatively few strikes for wage
# increases. Canadian farmers have not
# received the legislative favoritism ac-
# corded that element here.
# surprising that the Dominion has been
# severely
# of its chief executive on October 18.
#
# It is true that Canada is devoting
# nearly half its national income to war
# production, whereas the
# figure for this country is still only about
# 20 per cent. But the “victory program”
# now being evolved in Washington calls
# for an even greater percentage concen-
# tration on defense than is now being
# made by Canada. And it would therefore
# seem to call for the same sort of con-
# Mackenzie King an-
# nounces.
#
# Normal Processes Changing.
#
# In any event, the new Canadian ex-
# periment, when it goes into effect next
# month, will be closely watched. It is
# described by Tom Moore, president of
# the Labor Congress of Canada, as the
# “longest step yet taken by any democracy
# toward the establishment of a totali-
# tarian state.” The criticism is subject
# to some discount. But there is no doubt
# that theprogram goes far to fulfill warn-
# ings that the war will not be won with-
# out fundamental alteration of the nor-
# mal processes of capitalistic society.
#
# The Canadian program, as outlined by
# Prime Minister Mackenzie King, calls for
# a ceiling on all prices except for goods
# going into the export trade. Rentals and
# public utility charges will be subject to
# the same definite limitations as food and
# clothing. The maximum price set for
# every commodity is to be that prevailing
# during the period between September
# 15 and October 11. In the words of the
# Canadian Prime Minister, ‘“:prices are to
# be halted at the level they have already
# reached.”
#
# Following the German model, price
# control in Canada will be balanced by
# complete governmental control of wages
# income. “Hencefor-
# ward,” says Mr. Mackenzie King, “no em-
# ployer in Canadian industry or com-
# merce may, without permission, increase
# his present basic wage rates.”’ Prices for
# farm products are also stabilized at cur-
# rent levels, under the jurisdiction of
# the Wartime Prices and Trade Board.
#
# There is a varied Canadian reaction
# to these drastic regulations. which ap-
# parently are to be put into effect by
# executive order.
#
# Collective Bargaining Out.
#
# The press reaction and that of Big
# Business is on the whole favorable. In-
# terference with profits, already sharply
# curtailed by taxation, is held to be less
# unfortunate than the advantages seen
# in the stabilization of wages. Agricul-
# tural criticism is tempered by assurance
# that subsidies will be employed to keep
# prices up to the maximum levels allowed.
# Labor criticism is predominantly hostile,
# which is scarcely surprising in view of
# the virtual elimination of collective bar-
# gaining. That step obviously threatens
# the entire trade union structure.
#
# Politically, the program seems safe,
# since it is sponsored by a liberal admin-
# istration_and in general favored by the
# conservative opposition. Enthusiastic
# support is given by Malcolm MacDonald,
# the British High Commissioner to Can-
# ada, who calls the program “a grand
#
# experiment.” But there is room for
# more than one interpretation of Mr.
# MacDonald's remark that: “This is
#
# ‘carrying things even farther than the
#
# measures taken in Britain.”
# The Canadian program for the control
#
#
#
#
#
# |
#
# |
#
# |
# |
# |
#
# |
#
# So it is not |
#
# startled by the radio address |
#
#
#
# |
#
# comparable |
#
# of wages and prices is arousing keen in-
# terest in Washington. It is made public
# as the lengthy hearings of the House
# Banking and Currency Committee on
# this general subject draw to a close.
# Nearly three critical months have passed
# since President Roosevelt, in his message
# of July 30, urgently requested price-
# control legislation. Now, before a bill to
# that end is even drafted, comes the swift
# and energetic Canadian action in this
# field.
#
# Some Differences Noted.
#
# Dr. Isador Lubin, the Commissioner of
# Labor Statistics, has told this House
# committee that there are reasons for the
# action of the Canadian government
# which have no applicability in the
# United States. One of these is that in-
# voluntary unemployment is now elimi-
# nated in Canada. The inference is that
# without full employment a ceiling on
# wages does not have so much advantage
# in discouraging competitive bidding for
# workers and therefore would not be s0
# effective in reducing turnover in war
# industries.
#
# In other respects, however, differences
# between the Canadian and American
# situations would seem to favor duplica-
# tion of the Canadian experiment here.
# Canada has had no experience of the
# epidemic of wage strikes in war indus-
# tries which has so materially impeded
# defense production here. And even be-
# fore promulgation of the new controls
#
# | the risk of a runaway price level, in
#
#
#
# a
#
# | overseas.
#
# Canada seemed less than in the United
# States.
#
# Mr. Mackenzie King’s bold program is
# indorsed in Canada both as a preventive
# of strikes and as an anti-inflationary
# measure. Particularly in the latter re-
# spect the results of the Canadian experi-
# ment are likely to prove influential in
# American thinking. For every one is
# now beginning to realize that present
# restrictive measures are not preventing
# a rapid price rise in the United States.
# This is now affecting living costs in a
# way which can no longer be concealed
# from the ultimate consumer.
#
# At Least Two Years More of War.
#
# The timing of the Canadian action is
# not without significance. It is announced
# by the Prime Minister, who recently
# returned from conferences with the
# British war cabinet, coincident with
# the accumulation of bad news from
# Russia. The successive disasters sus-
# tained by the Russians are taken to
# mean that the defeat of Germany will
# require at least two more years of war.
# It is with a view to that eventuality,
# and all implied thereby, that Canada is
# imposing rigorous Federal controls over
# prices, rentals, wages and farm incomes.
#
# Canada is an active belligerent, sus-
# taining 2 substantial expeditionary force
# Theoretically, the United
# States is still at peace. Our people are
# only just beginning to think of this
# country as a reservoir of manpower as
# well as an arsenal of democracy. But
# as we move nearer large-scale hostilities,
# the necessity of Government controls
# never before anticipated for this coun-
# try will become evident. Germany will
# never be defeated on a program of busi-
# ness as usual.
#
# That is the real moral for this country
# in the drastic measures now being ap-
# plied in Canada. And that is why Wash-
# ington, which is usually rather indiffer-
# ent to Canadian occurrences, has in this
# instance sent officials of O. P. A. flying
# posthaste to Ottawa. They have noted,
# incidentally, that the program an-
# nounced by Mr. Mackenzie King is not
# merely @ wartime measure but is to be
# continued after the war “to facilitate
# recovery and reconstruction.”
#
# There is no comment from Berlin on
# this evidence that Canada, at least, re-
# gards the war as being still in its open-
# ing stages. But if imitation is the sin-
# cerest form of flattery there must be
# some gratification mingled with whaet-
# ever anxiety the Nazis feel.
#
# When they put price and wage con-
# trols into effect, the move was denounced
# on this side of the Atlantic as a sign of
# economic weakness and_ dictatorial
# predeliction. Now Mr. Mackenzie King
#
# edopts even the “guns versus .butter”
# justification in applying to Canada the
# same controls which Marshal Goering
# ordered for Germany five years ago.
#
# na
#
# erin bese

# %%
scnewtext, _ = bing_spellcheck(newtext)

# %%
hd = HtmlDiff()
tbl = hd.make_table(nltk.word_tokenize(sctext), nltk.word_tokenize(scnewtext), 
                    fromdesc='sctext', todesc='scnewtext', context=True, numlines=0)
display.HTML(tbl)
# Out:
#     <table class="diff" id="difflib_chg_to1__top"
#            cellspacing="0" cellpadding="0" rules="groups" >
#         <colgroup></colgroup> <colgroup></colgroup> <colgroup></colgroup>
#         <colgroup></colgroup> <colgroup></colgroup> <colgroup></colgroup>
#         <thead><tr><th class="diff_next"><br /></th><th colspan="2" class="diff_header">sctext</th><th class="diff_next"><br /></th><th colspan="2" class="diff_header">scnewtext</th></tr></thead>
#         <tbody>
#             <tr><td class="diff_next" id="difflib_chg_to1__0"><a href="#difflib_chg_to1__1">n</a></td><td class="diff_header" id="from1_1">1</td><td nowrap="nowrap"><span class="diff_sub">ss</span></td><td class="diff_next"><a href="#difflib_chg_to1__1">n</a></td><td class="diff_header" id="to1_1">1</td><td nowrap="nowrap"><span class="diff_add">Editorial</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_2">2</td><td nowrap="nowrap"><span class="diff_sub">;</span></td><td class="diff_next"></td><td class="diff_header" id="to1_2">2</td><td nowrap="nowrap"><span class="diff_add">Page</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_3">3</td><td nowrap="nowrap"><span class="diff_sub">-</span></td><td class="diff_next"></td><td class="diff_header" id="to1_3">3</td><td nowrap="nowrap"><span class="diff_add">Features</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_4">4</td><td nowrap="nowrap"><span class="diff_sub">-</span></td><td class="diff_next"></td><td class="diff_header" id="to1_4">4</td><td nowrap="nowrap"><span class="diff_add">.</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_5">5</td><td nowrap="nowrap"><span class="diff_sub">pje</span></td><td class="diff_next"></td><td class="diff_header" id="to1_5">5</td><td nowrap="nowrap"><span class="diff_add">The</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_6">6</td><td nowrap="nowrap"><span class="diff_sub">pumky</span></td><td class="diff_next"></td><td class="diff_header" id="to1_6">6</td><td nowrap="nowrap"><span class="diff_add">Summary</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_7">7</td><td nowrap="nowrap"><span class="diff_sub">Pte</span></td><td class="diff_next"></td><td class="diff_header" id="to1_7">7</td><td nowrap="nowrap"><span class="diff_add">Star</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_8">8</td><td nowrap="nowrap"><span class="diff_sub">'</span></td><td class="diff_next"></td><td class="diff_header" id="to1_8">8</td><td nowrap="nowrap"><span class="diff_add">Civics</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_9">9</td><td nowrap="nowrap"><span class="diff_sub">N</span></td><td class="diff_next"></td><td class="diff_header" id="to1_9">9</td><td nowrap="nowrap"><span class="diff_add">Organization</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_10">10</td><td nowrap="nowrap"><span class="diff_sub">,</span></td><td class="diff_next"></td><td class="diff_header" id="to1_10">10</td><td nowrap="nowrap"><span class="diff_add">News</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_11">11</td><td nowrap="nowrap"><span class="diff_sub">ws</span></td><td class="diff_next"></td><td class="diff_header" id="to1_11">11</td><td nowrap="nowrap"><span class="diff_add">TEN</span></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_12">12</td><td nowrap="nowrap"><span class="diff_sub">b</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_13">13</td><td nowrap="nowrap"><span class="diff_sub">TEX</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#         </tbody>
#         <tbody>
#             <tr><td class="diff_next" id="difflib_chg_to1__1"><a href="#difflib_chg_to1__2">n</a></td><td class="diff_header" id="from1_16">16</td><td nowrap="nowrap"><span class="diff_sub">WASHINGTON</span></td><td class="diff_next"><a href="#difflib_chg_to1__2">n</a></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_17">17</td><td nowrap="nowrap"><span class="diff_sub">,</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_18">18</td><td nowrap="nowrap"><span class="diff_sub">D.</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_19">19</td><td nowrap="nowrap"><span class="diff_sub">C.</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_20">20</td><td nowrap="nowrap"><span class="diff_sub">,</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_21">21</td><td nowrap="nowrap"><span class="diff_sub">OCTOBER</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_22">22</td><td nowrap="nowrap"><span class="diff_sub">26</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_23">23</td><td nowrap="nowrap"><span class="diff_sub">,</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_24">24</td><td nowrap="nowrap"><span class="diff_sub">1941</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_25">25</td><td nowrap="nowrap"><span class="diff_sub">.</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_26">26</td><td nowrap="nowrap"><span class="diff_sub">--</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_27">27</td><td nowrap="nowrap"><span class="diff_sub">--</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_28">28</td><td nowrap="nowrap"><span class="diff_sub">-</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_29">29</td><td nowrap="nowrap"><span class="diff_sub">-</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_30">30</td><td nowrap="nowrap"><span class="diff_sub">--</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from1_31">31</td><td nowrap="nowrap"><span class="diff_sub">-r</span></td><td class="diff_next"></td><td class="diff_header"></td><td nowrap="nowrap"></td></tr>
#             <tr><td class="diff_next"></td><td class="d

# %% [markdown]
# # NLTK

# %% [markdown]
# Here I try comparing word frequencies in our serach result with the [Brown Corpus](https://en.wikipedia.org/wiki/Brown_Corpus) to identify words that are more common in the search result pages than in American English writing in general.
#
# This is more useful as an illustration of the technique than for producing useful information, owing to some limitations of the Brown Corpus:
# * It's relatively small (about 500 writing samples, ~1,000,000 words.
# * The text dates from 1961. Results based on it probably won't be relevant for the older texts in the _Chronicling America_ collection.
# * _Brown_ is intentionally diverse, containing a variety of writing styles. Some of the "uncommon words" here might just be "newspaper speak" rather than unusual words.

# %%
#Get a list of common words that add no real information.
sws = stopwords.words('english')

# %%
#Get word frequencies from the Brown Corpus.
brownfreqs = Counter(word.lower() for word in brown.words())
brownlen = len(brown.words())
brownprobs = {k: v/brownlen for k, v in brownfreqs.items()}

# %%
#Get word frequencies on our page, minus stopwords.
wordfreqs = Counter(word.lower() for word in nltk.word_tokenize(sctext) 
                            if not (word in sws or len(word) < 4))
textlen = len(nltk.word_tokenize(sctext))
wordprobs = {k: v/textlen for k, v in wordfreqs.items()}

#Get differences in word frequencies in our page vs. Brown.
upwords = {k: v - brownprobs.get(k, 1) for k, v in wordprobs.items()}

# %%
sorted(upwords.items(), key=itemgetter(1), reverse=True)[:30]
# Out:
# [('hitler', 0.005094311778419546),
#  ('canada', 0.0030972624451515904),
#  ('japanese', 0.0025872353115259533),
#  ('german', 0.0025596774227358136),
#  ('canadian', 0.0024622948976096154),
#  ('would', 0.002434838049499022),
#  ('germany', 0.0020694575216780894),
#  ('united', 0.0018886776068288143),
#  ('siberia', 0.0018049365654256517),
#  ('japan', 0.0017773786766355118),
#  ('russia', 0.0017480984197959883),
#  ('states', 0.0016199194607889342),
#  ('program', 0.0014707971638452067),
#  ('people', 0.0014097905587641183),
#  ('king', 0.0014052097172965908),
#  ('masses', 0.001298354167898782),
#  ('government', 0.0012855738682004381),
#  ('political', 0.001258808433098973),
#  ('price', 0.0012234311577505894),
#  ('order', 0.0011571887181853326),
#  ('world', 0.0011323518421413024),
#  ('prices', 0.0010993519278589435),
#  ('support', 0.000996871028920611),
#  ('control', 0.0009598401158588607),
#  ('criticism', 0.0009528819133253088),
#  ('wages', 0.000951159545275925),
#  ('wage', 0.0009391029689302388),
#  ('words', 0.0009159197305995755),
#  ('great', 0.0009083065350493826),
#  ('books', 0.0009046556079425641)]

# %% [markdown]
# # Entity Recognition
#
# I tried two methods to find important terms in the text.

# %% [markdown]
# ## TextBlob

# %% [markdown]
# For my first attempt I used [TextBlob](https://textblob.readthedocs.io/en/dev/)'s part-of-speech tagging and looked for groups of proper nouns.

# %%
textb = TextBlob(sctext)

# %%
textb.tags[:100]
# Out:
# [('ss', 'NN'),
#  ('pje', 'NN'),
#  ('pumky', 'NN'),
#  ('Pte', 'NNP'),
#  ("'", 'POS'),
#  ('N', 'NNP'),
#  ('ws', 'NN'),
#  ('b', 'NN'),
#  ('TEX', 'NNP'),
#  ('PAGES', 'NNP'),
#  ('WASHINGTON', 'NNP'),
#  ('D.', 'NNP'),
#  ('C.', 'NNP'),
#  ('OCTOBER', 'NNP'),
#  ('26', 'CD'),
#  ('1941', 'CD'),
#  ('-r', 'NN'),
#  ('n', 'NN'),
#  ('War', 'NNP'),
#  ('With', 'IN'),
#  ('U.', 'NNP'),
#  ('S.', 'NNP'),
#  ('Seen', 'NNP'),
#  ('Inevitable', 'NNP'),
#  ('If', 'IN'),
#  ('Tokio', 'NNP'),
#  ('Plays', 'NNP'),
#  ('for', 'IN'),
#  ('Big', 'NNP'),
#  ('Stakes', 'NNP'),
#  ('Little', 'NNP'),
#  ('Opposition', 'NNP'),
#  ('Likely', 'NNP'),
#  ('in', 'IN'),
#  ('Congress', 'NNP'),
#  ('to', 'TO'),
#  ('Settling', 'VBG'),
#  ('Scores', 'NNS'),
#  ('With', 'IN'),
#  ('Japan', 'NNP'),
#  ('if', 'IN'),
#  ('Nipponese', 'JJ'),
#  ('Push', 'NNP'),
#  ('Plan', 'NN'),
#  ('to', 'TO'),
#  ('Attack', 'VB'),
#  ('Siberia', 'NNP'),
#  ('By', 'IN'),
#  ('Constantine', 'NNP'),
#  ('Brown', 'NNP'),
#  ('Administrative', 'JJ'),
#  ('quarters', 'NNS'),
#  ('in', 'IN'),
#  ('Washington', 'NNP'),
#  ('and', 'CC'),
#  ('most', 'JJS'),
#  ('members', 'NNS'),
#  ('of', 'IN'),
#  ('Congress', 'NNP'),
#  ('including', 'VBG'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('inveterate', 'NN'),
#  ('isolationists', 'NNS'),
#  ('are', 'VBP'),
#  ('reported', 'VBN'),
#  ('to', 'TO'),
#  ('share', 'NN'),
#  ('Navy', 'NNP'),
#  ('Secretary', 'NNP'),
#  ('Knox', 'NNP'),
#  ('s', 'JJ'),
#  ('belief', 'NN'),
#  ('that', 'WDT'),
#  ('war', 'NN'),
#  ('between', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('States', 'NNPS'),
#  ('and', 'CC'),
#  ('Japan', 'NNP'),
#  ('is', 'VBZ'),
#  ('almost', 'RB'),
#  ('Inevitable', 'JJ'),
#  ('If', 'IN'),
#  ('the', 'DT'),
#  ('Moscow', 'NNP'),
#  ('front', 'NN'),
#  ('collapses', 'NNS'),
#  ('the', 'DT'),
#  ('personal', 'JJ'),
#  ('position', 'NN'),
#  ('of', 'IN'),
#  ('Joseph', 'NNP'),
#  ('Stalin', 'NNP'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('in', 'IN'),
#  ('jeopardy', 'NN')]

# %%
#Get a list of just proper nouns.
[(idx, word) for idx, (word, pos) in enumerate(textb.tags) if pos in ('NNP', 'NNPS')][:100]
# Out:
# [(3, 'Pte'),
#  (5, 'N'),
#  (8, 'TEX'),
#  (9, 'PAGES'),
#  (10, 'WASHINGTON'),
#  (11, 'D.'),
#  (12, 'C.'),
#  (13, 'OCTOBER'),
#  (18, 'War'),
#  (20, 'U.'),
#  (21, 'S.'),
#  (22, 'Seen'),
#  (23, 'Inevitable'),
#  (25, 'Tokio'),
#  (26, 'Plays'),
#  (28, 'Big'),
#  (29, 'Stakes'),
#  (30, 'Little'),
#  (31, 'Opposition'),
#  (32, 'Likely'),
#  (34, 'Congress'),
#  (39, 'Japan'),
#  (42, 'Push'),
#  (46, 'Siberia'),
#  (48, 'Constantine'),
#  (49, 'Brown'),
#  (53, 'Washington'),
#  (58, 'Congress'),
#  (69, 'Navy'),
#  (70, 'Secretary'),
#  (71, 'Knox'),
#  (78, 'United'),
#  (79, 'States'),
#  (81, 'Japan'),
#  (87, 'Moscow'),
#  (94, 'Joseph'),
#  (95, 'Stalin'),
#  (110, 'U.'),
#  (111, 'S.'),
#  (112, 'R.'),
#  (119, 'Japanese'),
#  (127, 'Italians'),
#  (135, 'France'),
#  (146, 'Tokyo'),
#  (153, 'Siberia'),
#  (155, 'Germans'),
#  (171, 'Japan'),
#  (185, 'Pacific'),
#  (197, 'Russia'),
#  (203, 'Japanese'),
#  (218, 'Nazis'),
#  (224, 'Moscow'),
#  (234, 'Hence'),
#  (235, 'Japan'),
#  (243, 'United'),
#  (244, 'States'),
#  (252, 'Japan'),
#  (260, 'Reich'),
#  (262, 'Tokyo'),
#  (265, 'Wait'),
#  (267, 'See'),
#  (277, 'Pacific'),
#  (280, 'Japan'),
#  (285, 'Axis'),
#  (308, 'Reich'),
#  (318, 'Ambassador'),
#  (323, 'Prince'),
#  (324, 'Premier'),
#  (325, 'Fumimaro'),
#  (326, 'Konoye'),
#  (336, 'Emperor'),
#  (345, 'Russia'),
#  (351, 'Nazi'),
#  (361, 'Reich'),
#  (365, 'Japan'),
#  (374, 'United'),
#  (375, 'States'),
#  (389, 'Russians'),
#  (394, 'Emperor'),
#  (415, 'Russia'),
#  (418, 'Hitler'),
#  (423, 'Emperor'),
#  (437, 'Axis'),
#  (439, 'Emperor'),
#  (440, 'Hirohito'),
#  (448, 'Japanese'),
#  (469, 'United'),
#  (470, 'States'),
#  (473, 'Vladivostok'),
#  (480, 'Washington'),
#  (482, 'Tokyo'),
#  (490, 'Big'),
#  (491, 'Stakes'),
#  (493, 'Tokyo'),
#  (501, 'Ambassador'),
#  (502, 'Joseph'),
#  (503, 'C.'),
#  (504, 'Grew'),
#  (545, 'United'),
#  (546, 'States')]

# %%
nnp = []

etags = enumerate(textb.tags)
for idx, (word, tag) in etags:
    if tag in ('NNP', 'NNPS'):
        newnnp = [idx, [word]]
        idx, (word, tag) = next(etags)
        while tag in ('NNP', 'NNPS'):
            newnnp[1].append(word)
            idx, (word, tag) = next(etags)
        nnp.append(newnnp)

len(nnp)
# Out:
# 387

# %% [markdown]
# Taking groups of consecutive proper nouns gives us

# %%
nnp[:100]
# Out:
# [[3, ['Pte']],
#  [5, ['N']],
#  [8, ['TEX', 'PAGES', 'WASHINGTON', 'D.', 'C.', 'OCTOBER']],
#  [18, ['War']],
#  [20, ['U.', 'S.', 'Seen', 'Inevitable']],
#  [25, ['Tokio', 'Plays']],
#  [28, ['Big', 'Stakes', 'Little', 'Opposition', 'Likely']],
#  [34, ['Congress']],
#  [39, ['Japan']],
#  [42, ['Push']],
#  [46, ['Siberia']],
#  [48, ['Constantine', 'Brown']],
#  [53, ['Washington']],
#  [58, ['Congress']],
#  [69, ['Navy', 'Secretary', 'Knox']],
#  [78, ['United', 'States']],
#  [81, ['Japan']],
#  [87, ['Moscow']],
#  [94, ['Joseph', 'Stalin']],
#  [110, ['U.', 'S.', 'R.']],
#  [119, ['Japanese']],
#  [127, ['Italians']],
#  [135, ['France']],
#  [146, ['Tokyo']],
#  [153, ['Siberia']],
#  [155, ['Germans']],
#  [171, ['Japan']],
#  [185, ['Pacific']],
#  [197, ['Russia']],
#  [203, ['Japanese']],
#  [218, ['Nazis']],
#  [224, ['Moscow']],
#  [234, ['Hence', 'Japan']],
#  [243, ['United', 'States']],
#  [252, ['Japan']],
#  [260, ['Reich']],
#  [262, ['Tokyo']],
#  [265, ['Wait']],
#  [267, ['See']],
#  [277, ['Pacific']],
#  [280, ['Japan']],
#  [285, ['Axis']],
#  [308, ['Reich']],
#  [318, ['Ambassador']],
#  [323, ['Prince', 'Premier', 'Fumimaro', 'Konoye']],
#  [336, ['Emperor']],
#  [345, ['Russia']],
#  [351, ['Nazi']],
#  [361, ['Reich']],
#  [365, ['Japan']],
#  [374, ['United', 'States']],
#  [389, ['Russians']],
#  [394, ['Emperor']],
#  [415, ['Russia']],
#  [418, ['Hitler']],
#  [423, ['Emperor']],
#  [437, ['Axis']],
#  [439, ['Emperor', 'Hirohito']],
#  [448, ['Japanese']],
#  [469, ['United', 'States']],
#  [473, ['Vladivostok']],
#  [480, ['Washington']],
#  [482, ['Tokyo']],
#  [490, ['Big', 'Stakes']],
#  [493, ['Tokyo']],
#  [501, ['Ambassador', 'Joseph', 'C.', 'Grew']],
#  [545, ['United', 'States']],
#  [561, ['Far', 'East']],
#  [592, ['TT', 'IUJ']],
#  [595, ['Steiner']],
#  [599, ['Japan']],
#  [604, ['Asiatic']],
#  [631, ['Tokio']],
#  [640, ['Russia']],
#  [647, ['Reich']],
#  [650, ['Hitler']],
#  [669, ['Nipponese']],
#  [694, ['Russians']],
#  [703, ['Tokio']],
#  [712, ['United', 'States']],
#  [720, ['Pacific']],
#  [727, ['Japanese']],
#  [749, ['America']],
#  [754, ['United', 'States', 'Gov']],
#  [766, ['Japan']],
#  [769, ['Siberia']],
#  [773, ['Phari']],
#  [784, ['Russia']],
#  [800, ['Communist']],
#  [806, ['Siberia']],
#  [811, ['Stalin']],
#  [815, ['Evrcee']],
#  [817, ['Asiatic']],
#  [821, ['U.', 'S.', 'S.']],
#  [883, ['Russia']],
#  [905, ['Germans']],
#  [916, ['Russia']],
#  [925, ['Siberia']],
#  [940, ['Siberia']],
#  [947, ['Japanese']]]

# %% [markdown]
# ## SpaCy
#
# [SpaCy](https://spacy.io/) is another natural language processing package. Here I try using its default entity recognition system on the text.

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# This gives us a reasonable-looking list of entities, tagged by what kind of thing each one is (_Person_, _Geo-political entity_, etc.).

# %%
scydoc = nlp(sctext)

[(ent.text, ent.start_char, ent.end_char, ent.label_) 
     for ent in scydoc.ents]
# Out:
# [('ss;-', 1, 5, 'ORG'),
#  ('TEX', 35, 38, 'ORG'),
#  ('WASHINGTON', 46, 56, 'GPE'),
#  ('D. C., OCTOBER 26, 1941', 58, 81, 'PERSON'),
#  ('War With U. S.', 104, 118, 'WORK_OF_ART'),
#  ('Nipponese', 235, 244, 'NORP'),
#  ('Attack Siberia', 258, 272, 'PERSON'),
#  ('Constantine Brown', 276, 293, 'PERSON'),
#  ('Administrative quarters', 295, 318, 'DATE'),
#  ('Washington', 322, 332, 'GPE'),
#  ('Congress', 353, 361, 'ORG'),
#  ('Navy', 431, 435, 'ORG'),
#  ('Knox s', 446, 452, 'PERSON'),
#  ('the United States', 477, 494, 'GPE'),
#  ('Japan', 499, 504, 'GPE'),
#  ('Inevitable', 515, 525, 'ORG'),
#  ('Moscow', 534, 540, 'GPE'),
#  ('Joseph Stalin', 583, 596, 'PERSON'),
#  ('the U. S.  R.', 678, 691, 'GPE'),
#  ('Japanese', 729, 737, 'NORP'),
#  ('Italians', 773, 781, 'NORP'),
#  ('1910', 792, 796, 'DATE'),
#  ('France', 815, 821, 'GPE'),
#  ('Soviet', 856, 862, 'NORP'),
#  ('Tokyo', 890, 895, 'GPE'),
#  ('Siberia', 930, 937, 'LOC'),
#  ('Germans', 943, 950, 'NORP'),
#  ('Nazi', 988, 992, 'NORP'),
#  ('Japan', 1044, 1049, 'GPE'),
#  ('American-Japanese', 1078, 1095, 'NORP'),
#  ('Pacific', 1143, 1150, 'LOC'),
#  ('German', 1175, 1181, 'NORP'),
#  ('Russia', 1222, 1228, 'GPE'),
#  ('Japanese', 1256, 1264, 'NORP'),
#  ('British', 1285, 1292, 'NORP'),
#  ('American', 1297, 1305, 'NORP'),
#  ('Nazis', 1347, 1352, 'NORP'),
#  ('Moscow', 1378, 1384, 'GPE'),
#  ('Soviet', 1419, 1425, 'NORP'),
#  ('Japan', 1450, 1455, 'GPE'),
#  ('the United States', 1490, 1507, 'GPE'),
#  ('Japan', 1556, 1561, 'GPE'),
#  ('Reich', 1601, 1606, 'PERSON'),
#  ('Tokyo', 1610, 1615, 'GPE'),
#  ('Pacific', 1697, 1704, 'LOC'),
#  ('Japan', 1718, 1723, 'GPE'),
#  ('German', 1779, 1785, 'NORP'),
#  ('Japanese', 1829, 1837, 'NORP'),
#  ('Reich', 1880, 1885, 'PERSON'),
#  ('German', 1925, 1931, 'NORP'),
#  ('Fumimaro Konoye', 1989, 2004, 'PERSON'),
#  ('Russia', 2100, 2106, 'GPE'),
#  ('Nazi', 2138, 2142, 'NORP'),
#  ('Reich', 2189, 2194, 'PERSON'),
#  ('Japan', 2208, 2213, 'GPE'),
#  ('the United States', 2252, 2269, 'GPE'),
#  ('Russians', 2339, 2347, 'NORP'),
#  ('the dynasty', 2460, 2471, 'DATE'),
#  ('Russia', 2493, 2499, 'GPE'),
#  ('Hirohito', 2635, 2643, 'PERSON'),
#  ('weeks', 2669, 2674, 'DATE'),
#  ('Japanese', 2679, 2687, 'NORP'),
#  ('United States', 2806, 2819, 'GPE'),
#  ('Washington', 2884, 2894, 'GPE'),
#  ('Tokyo', 2899, 2904, 'GPE'),
#  ('Tokyo', 2966, 2971, 'GPE'),
#  ('Joseph C. Grew', 3033, 3047, 'PERSON'),
#  ('The United States', 3280, 3297, 'GPE'),
#  ('the Far East', 3374, 3386, 'LOC'),
#  ('11', 3562, 3564, 'CARDINAL'),
#  ('TT', 3565, 3567, 'ORG'),
#  ('IUJ', 3569, 3572, 'ORG'),
#  ('Japan', 3601, 3606, 'GPE'),
#  ('Asiatic', 3626, 3633, 'LOC'),
#  ('nearly 10 weeks', 3648, 3663, 'DATE'),
#  ('Japanese', 3668, 3676, 'NORP'),
#  ('Russian', 3739, 3746, 'NORP'),
#  ('Tokio', 3794, 3799, 'PERSON'),
#  ('German', 3837, 3843, 'NORP'),
#  ('Russia', 3860, 3866, 'GPE'),
#  ('Reich', 3891, 3896, 'PERSON'),
#  ('Hitler', 3906, 3912, 'PERSON'),
#  ('a million', 3959, 3968, 'CARDINAL'),
#  ('German', 3983, 3989, 'NORP'),
#  ('Nipponese', 4016, 4025, 'NORP'),
#  ('Russians', 4152, 4160, 'NORP'),
#  ('Tokio', 4204, 4209, 'PERSON'),
#  ('the United States', 4261, 4278, 'GPE'),
#  ('Pacific', 4303, 4310, 'LOC'),
#  ('Japanese', 4349, 4357, 'NORP'),
#  ('America', 4469, 4476, 'GPE'),
#  ('the United States', 4492, 4509, 'GPE'),
#  ('Japan', 4578, 4583, 'GPE'),
#  ('Siberia', 4594, 4601, 'LOC'),
#  ('Phari', 4621, 4626, 'ORG'),
#  ('Japanese', 4665, 4673, 'NORP'),
#  ('Russia', 4682, 4688, 'GPE'),
#  ('hundreds of thousands', 4729, 4750, 'CARDINAL'),
#  ('millions', 4759, 4767, 'CARDINAL'),
#  ('Communist', 4772, 4781, 'NORP'),
#  ('Siberia', 4809, 4816, 'LOC'),
#  ('Stalin', 4837, 4843, 'PERSON'),
#  ('Evrcee', 4856, 4862, 'GPE'),
#  ('Asiatic', 4868, 4875, 'GPE'),
#  ('the U. S. S.', 4887, 4899, 'GPE'),
#  ('Siberian', 5118, 5126, 'NORP'),
#  ('a few years', 5161, 5172, 'DATE'),
#  ('Russia', 5216, 5222, 'GPE'),
#  ('millions', 5274, 5282, 'CARDINAL'),
#  ('millions', 5300, 5308, 'CARDINAL'),
#  ('Germans', 5343, 5350, 'NORP'),
#  ('Russia', 5411, 5417, 'GPE'),
#  ('Japanese', 5438, 5446, 'NORP'),
#  ('Siberia', 5462, 5469, 'LOC'),
#  ('Siberia', 5552, 5559, 'LOC'),
#  ('Japanese', 5587, 5595, 'NORP'),
#  ('Manchukuo', 5606, 5615, 'PRODUCT'),
#  ('the Nipponese Empire', 5674, 5694, 'GPE'),
#  ('j Soon', 5696, 5702, 'PERSON'),
#  ('Rus', 5774, 5777, 'PERSON'),
#  ('Manchukuo I and China', 5809, 5830, 'ORG'),
#  ('Japan', 5896, 5901, 'GPE'),
#  ('Settle Question', 5917, 5932, 'ORG'),
#  ('Japanese', 5951, 5959, 'NORP'),
#  ('Japanese', 6279, 6287, 'NORP'),
#  ('Siberia', 6320, 6327, 'LOC'),
#  ('Communist', 6405, 6414, 'NORP'),
#  ('Asia', 6425, 6429, 'LOC'),
#  ('Japanese', 6453, 6461, 'NORP'),
#  ('Japanese', 6546, 6554, 'NORP'),
#  ('Siberia', 6557, 6564, 'LOC'),
#  ('the Nipponese Empire', 6607, 6627, 'GPE'),
#  ('Japanese', 6673, 6681, 'NORP'),
#  ('Russian', 6739, 6746, 'NORP'),
#  ('Siberia', 6769, 6776, 'LOC'),
#  ('Japan', 6820, 6825, 'GPE'),
#  ('Aryan', 6853, 6858, 'PERSON'),
#  ('China', 6894, 6899, 'GPE'),
#  ('Tokio', 6931, 6936, 'PERSON'),
#  ('Siberian', 6952, 6960, 'NORP'),
#  ('1905', 7000, 7004, 'DATE'),
#  ('Japanese', 7108, 7116, 'NORP'),
#  ('America', 7153, 7160, 'GPE'),
#  ('American', 7196, 7204, 'NORP'),
#  ('Siberia', 7235, 7242, 'LOC'),
#  ('Russian', 7297, 7304, 'NORP'),
#  ('Asiatic', 7318, 7325, 'GPE'),
#  ('U. S. Assistance Pledged', 7338, 7362, 'PERSON'),
#  ('the White House', 7447, 7462, 'ORG'),
#  ('Jap anese', 7514, 7523, 'NORP'),
#  ('Manchukuo Siberian', 7541, 7559, 'PRODUCT'),
#  ('three', 7730, 7735, 'CARDINAL'),
#  ('the Par East', 7745, 7757, 'LOC'),
#  ('The United States', 7759, 7776, 'GPE'),
#  ('Soviet', 8000, 8006, 'NORP'),
#  ('Siberia', 8015, 8022, 'LOC'),
#  ('Japanese', 8042, 8050, 'NORP'),
#  ('Hitler', 8074, 8080, 'PERSON'),
#  ('Stalin', 8110, 8116, 'PERSON'),
#  ('Soviet', 8180, 8186, 'NORP'),
#  ('Jack Lambert', 8306, 8318, 'PERSON'),
#  ('Raymond P. Brandt', 8392, 8409, 'PERSON'),
#  ('two', 8482, 8485, 'CARDINAL'),
#  ('-more than 1.000', 8503, 8519, 'CARDINAL'),
#  ('English', 8549, 8556, 'LANGUAGE'),
#  ('Reynal and Hitchcock', 8560, 8580, 'ORG'),
#  ('first', 8586, 8591, 'ORDINAL'),
#  ('Mein Kampf', 8613, 8623, 'PERSON'),
#  ('Hitler', 8636, 8642, 'PERSON'),
#  ('1924', 8646, 8650, 'DATE'),
#  ('1926', 8655, 8659, 'DATE'),
#  ('second', 8665, 8671, 'ORDINAL'),
#  ('"My New Order', 8675, 8688, 'WORK_OF_ART'),
#  ('French', 8734, 8740, 'NORP'),
#  ('Raoul de Roussy de Sales', 8752, 8776, 'PERSON'),
#  ('Mein Kampf', 8807, 8817, 'PERSON'),
#  ('Hitlerian', 8830, 8839, 'NORP'),
#  ('June 22', 8873, 8880, 'DATE'),
#  ('Soviet', 8908, 8914, 'NORP'),
#  ('Russia', 8915, 8921, 'GPE'),
#  ('Germany', 9009, 9016, 'GPE'),
#  ('Hitler', 9022, 9028, 'PERSON'),
#  ('first', 9031, 9036, 'ORDINAL'),
#  ('Munich', 9057, 9063, 'GPE'),
#  ('April, 1222', 9067, 9078, 'DATE'),
#  ('M. de Sales', 9089, 9100, 'PERSON'),
#  ('London', 9200, 9206, 'GPE'),
#  ('Paris', 9208, 9213, 'GPE'),
#  ('New York', 9218, 9226, 'GPE'),
#  ('Mein', 9385, 9389, 'PERSON'),
#  ('the Bible of the Third Reich', 9400, 9428, 'WORK_OF_ART'),
#  ('millions', 9436, 9444, 'CARDINAL'),
#  ('hundreds of thousands', 9497, 9518, 'CARDINAL'),
#  ('England', 9684, 9691, 'GPE'),
#  ('France', 9694, 9700, 'GPE'),
#  ('Russia', 9702, 9708, 'GPE'),
#  ('Balkans', 9717, 9724, 'LOC'),
#  ('Americans', 9790, 9799, 'NORP'),
#  ('Hitler', 9827, 9833, 'PERSON'),
#  ('Germans', 10068, 10075, 'NORP'),
#  ('the World War', 10218, 10231, 'EVENT'),
#  ('Hitler', 10248, 10254, 'PERSON'),
#  ('one', 10388, 10391, 'CARDINAL'),
#  ('Hitler', 10470, 10476, 'PERSON'),
#  ('German', 10544, 10550, 'NORP'),
#  ('Huey Long', 10672, 10681, 'PERSON'),
#  ('Carlyle', 10942, 10949, 'PERSON'),
#  ('Marxian', 11006, 11013, 'NORP'),
#  ('Hitler', 11098, 11104, 'PERSON'),
#  ('Germanic', 11218, 11226, 'PERSON'),
#  ('German', 11257, 11263, 'NORP'),
#  ('Germany', 11302, 11309, 'GPE'),
#  ('one', 11366, 11369, 'CARDINAL'),
#  ('German', 11559, 11565, 'NORP'),
#  ('German', 11592, 11598, 'NORP'),
#  ('German', 11737, 11743, 'NORP'),
#  ('Carlyle', 11871, 11878, 'PERSON'),
#  ('Marxian', 11898, 11905, 'NORP'),
#  ('three years later', 11939, 11956, 'DATE'),
#  ('Hitler', 11963, 11969, 'PERSON'),
#  ('European', 12037, 12045, 'NORP'),
#  ('Adolf Hitler', 12261, 12273, 'PERSON'),
#  ('two', 12363, 12366, 'CARDINAL'),
#  ('a hundred', 12530, 12539, 'CARDINAL'),
#  ('German', 12579, 12585, 'NORP'),
#  ('Francis Hackett', 12740, 12755, 'PERSON'),
#  ('America', 12840, 12847, 'GPE'),
#  ('American', 12857, 12865, 'NORP'),
#  ('Germany', 12896, 12903, 'GPE'),
#  ('Hitlerian', 12952, 12961, 'NORP'),
#  ('German Workers  Party', 13112, 13133, 'ORG'),
#  ('My New Order', 13321, 13333, 'LOC'),
#  ('M. de Sales', 13336, 13347, 'PERSON'),
#  ('Hitler', 13360, 13366, 'PERSON'),
#  ('Hitler', 13473, 13479, 'PERSON'),
#  ('Stuka', 13929, 13934, 'LOC'),
#  ('Mein Kampf.', 14407, 14418, 'PERSON'),
#  ('Hitler', 14535, 14541, 'PERSON'),
#  ('Austrian', 14606, 14614, 'NORP'),
#  ('the World War', 14697, 14710, 'EVENT'),
#  ('German', 14907, 14913, 'NORP'),
#  ('Germany', 14948, 14955, 'GPE'),
#  ('Germans', 15178, 15185, 'NORP'),
#  ('Hitler', 15230, 15236, 'PERSON'),
#  ('Germany', 15255, 15262, 'GPE'),
#  ('Versailles', 15327, 15337, 'LOC'),
#  ('the Weimer Republic', 15339, 15358, 'GPE'),
#  ('the Social Democratic', 15403, 15424, 'NORP'),
#  ('Communist', 15429, 15438, 'NORP'),
#  ('Hapsburg', 15493, 15501, 'GPE'),
#  ('Hohenzollern', 15506, 15518, 'NORP'),
#  ('Soviet', 15520, 15526, 'NORP'),
#  ('Russia', 15527, 15533, 'GPE'),
#  ('France', 15535, 15541, 'GPE'),
#  ('Jews', 15588, 15592, 'NORP'),
#  ('Junkers', 15688, 15695, 'PERSON'),
#  ('Germans', 15845, 15852, 'NORP'),
#  ('Frederick the Great', 15861, 15880, 'PERSON'),
#  ('Wagner', 15882, 15888, 'PERSON'),
#  ('Von Hindenberg', 15893, 15907, 'PERSON'),
#  ('two', 15965, 15968, 'CARDINAL'),
#  ('the National Socialist party', 16032, 16060, 'ORG'),
#  ('Reichstag', 16117, 16126, 'ORG'),
#  ('Germany', 16213, 16220, 'GPE'),
#  ('Europe', 16253, 16259, 'LOC'),
#  ('Hitler', 16373, 16379, 'PERSON'),
#  ('two', 16392, 16395, 'CARDINAL'),
#  ('Communists', 16431, 16441, 'NORP'),
#  ('Storm Troopers', 16456, 16470, 'PERSON'),
#  ('Nazis', 16485, 16490, 'NORP'),
#  ('Socialists', 16528, 16538, 'NORP'),
#  ('Communists', 16543, 16553, 'NORP'),
#  ('The Storm Troopers', 16719, 16737, 'ORG'),
#  ('Nazi', 16752, 16756, 'NORP'),
#  ('Huiwranc', 16880, 16888, 'PERSON'),
#  ('German', 17090, 17096, 'NORP'),
#  ('Huey Long', 17263, 17272, 'PERSON'),
#  ('Hitler', 17335, 17341, 'PERSON'),
#  ('Mein', 17348, 17352, 'PERSON'),
#  ('Hitler', 17759, 17765, 'PERSON'),
#  ('1', 17967, 17968, 'CARDINAL'),
#  ('One', 18049, 18052, 'CARDINAL'),
#  ('Just as a hundred', 18214, 18231, 'CARDINAL'),
#  ('a hundred', 18310, 18319, 'CARDINAL'),
#  ('Volkischer Beobachter', 18427, 18448, 'PERSON'),
#  ('Goddess of Misery', 18903, 18920, 'FAC'),
#  ('Hitler', 19071, 19077, 'PERSON'),
#  ('Fritz Thyssen', 19166, 19179, 'PERSON'),
#  ('Nuremberg', 19228, 19237, 'GPE'),
#  ('September, 1833', 19241, 19256, 'DATE'),
#  ('Mein', 19522, 19526, 'PERSON'),
#  ('Hitler', 19540, 19546, 'PERSON'),
#  ('Germany', 19573, 19580, 'GPE'),
#  ('a thousand years', 19600, 19616, 'DATE'),
#  ('1', 19721, 19722, 'CARDINAL'),
#  ('Mein TCflmnf', 19750, 19762, 'PERSON'),
#  ('Mv Npu', 19782, 19788, 'WORK_OF_ART'),
#  ('Hitler', 19870, 19876, 'PERSON'),
#  ('Hamburg', 19983, 19990, 'GPE'),
#  ('1934', 20003, 20007, 'DATE'),
#  ('14 years', 20440, 20448, 'DATE'),
#  ('Hitler', 20729, 20735, 'PERSON'),
#  ('the Industry  Club of Duesseldorf', 21621, 21654, 'ORG'),
#  ('January, 1932', 21658, 21671, 'DATE'),
#  ('Hitler', 21682, 21688, 'PERSON'),
#  ('Jews', 21810, 21814, 'NORP'),
#  ('Hitler', 21816, 21822, 'PERSON'),
#  ('German', 22328, 22334, 'NORP'),
#  ('Communism', 22364, 22373, 'NORP'),
#  ('Berlin', 22404, 22410, 'GPE'),
#  ('Com', 22468, 22471, 'ORG'),
#  ('Hitler', 22518, 22524, 'PERSON'),
#  ('Bolshevism', 22650, 22660, 'ORG'),
#  ('50 per cent', 22665, 22676, 'MONEY'),
#  ('Nationalists', 22681, 22693, 'NORP'),
#  ('anti-Bol', 22698, 22706, 'NORP'),
#  ('Germany', 22749, 22756, 'GPE'),
#  ('Bolshevist', 22764, 22774, 'NORP'),
#  ('Germany', 22866, 22873, 'GPE'),
#  ('Germany', 22961, 22968, 'GPE'),
#  ('50 per cent', 22972, 22983, 'MONEY'),
#  ('Bolshevists', 23004, 23015, 'PERSON'),
#  ('50 per cent', 23020, 23031, 'MONEY'),
#  ('A Gangster Plus', 23104, 23119, 'WORK_OF_ART'),
#  ('David Cushman Coyle', 23270, 23289, 'PERSON'),
#  ('America', 23337, 23344, 'GPE'),
#  ('Hitler', 23356, 23362, 'PERSON'),
#  ('Storm Troopers', 23368, 23382, 'WORK_OF_ART'),
#  ('Ges', 23391, 23394, 'PERSON'),
#  ('Hitler', 23562, 23568, 'PERSON'),
#  ('Huey Long', 23654, 23663, 'PERSON'),
#  ('today', 23714, 23719, 'DATE'),
#  ('1933', 23732, 23736, 'DATE'),
#  ('non-Germans', 23758, 23769, 'NORP'),
#  ('Hitler', 23782, 23788, 'PERSON'),
#  ('Charlie Chaplin', 23804, 23819, 'PERSON'),
#  ('"Mein Kampf  even then was available in English.',
#   23920,
#   23968,
#   'WORK_OF_ART'),
#  ('Britain', 23993, 24000, 'GPE'),
#  ('America', 24005, 24012, 'GPE'),
#  ('one', 24049, 24052, 'CARDINAL'),
#  ('M. De Sales', 24130, 24141, 'PERSON'),
#  ('Page B-', 24181, 24188, 'PERSON'),
#  ('Two', 24252, 24255, 'CARDINAL'),
#  ('Felix M', 24353, 24360, 'PERSON'),
#  ('Prom', 24368, 24372, 'GPE'),
#  ('Ottawa', 24373, 24379, 'GPE'),
#  ('Mackenzie King', 24384, 24398, 'PERSON'),
#  ('Canada', 24442, 24448, 'GPE'),
#  ('Germany', 24455, 24462, 'GPE'),
#  ('Canadian', 24519, 24527, 'NORP'),
#  ("Marshal Goering's", 24560, 24577, 'ORG'),
#  ('Dominion', 24670, 24678, 'ORG'),
#  ('the United States', 24683, 24700, 'GPE'),
#  ('Canada', 24723, 24729, 'GPE'),
#  ('November 15', 24786, 24797, 'DATE'),
#  ('Canada', 24911, 24917, 'GPE'),
#  ('the United States', 24926, 24943, 'GPE'),
#  ('Mac-', 25002, 25006, 'PERSON'),
#  ('kenzie King', 25009, 25020, 'PERSON'),
#  ('Canada', 25077, 25083, 'GPE'),
#  ('Canadian', 25177, 25185, 'NORP'),
#  ('Dominion', 25304, 25312, 'ORG'),
#  ('October 18', 25389, 25399, 'DATE'),
#  ('Canada', 25417, 25423, 'GPE'),
#  ('nearly half', 25436, 25447, 'CARDINAL'),
#  ('20 per cent', 25558, 25569, 'MONEY'),
#  ('Washington', 25617, 25627, 'GPE'),
#  ('Canada', 25720, 25726, 'GPE'),
#  ('Mackenzie King', 25804, 25818, 'PERSON'),
#  ('Canadian', 25880, 25888, 'NORP'),
#  ('next month', 25926, 25936, 'DATE'),
#  ('Tom Moore', 25982, 25991, 'PERSON'),
#  ('the Labor Congress of Canada', 26006, 26034, 'ORG'),
#  ('Canadian', 26357, 26365, 'NORP'),
#  ('Mackenzie King', 26405, 26419, 'PERSON'),
#  ('September 15 and October 11', 26700, 26727, 'DATE'),
#  ('Canadian', 26749, 26757, 'NORP'),
#  ('German', 26852, 26858, 'NORP'),
#  ('Canada', 26883, 26889, 'GPE'),
#  ('Henceforward', 26974, 26986, 'PERSON'),
#  ('Mackenzie King', 26997, 27011, 'PERSON'),
#  ('Canadian', 27028, 27036, 'NORP'),
#  ('the Wartime Prices and Trade Board', 27213, 27247, 'ORG'),
#  ('Canadian', 27266, 27274, 'NORP'),
#  ('Bargaining Out', 27388, 27402, 'ORG'),
#  ('Big Business', 27435, 27447, 'ORG'),
#  ('Malcolm MacDonald', 28128, 28145, 'PERSON'),
#  ('British', 28151, 28158, 'NORP'),
#  ('Canada', 28180, 28186, 'GPE'),
#  ('more than one', 28253, 28266, 'CARDINAL'),
#  ('MacDonald', 28289, 28298, 'PERSON'),
#  ('Britain', 28378, 28385, 'GPE'),
#  ('Canadian', 28391, 28399, 'NORP'),
#  ('Washington', 28474, 28484, 'GPE'),
#  ('the House Banking and Currency Committee', 28531, 28571, 'ORG'),
#  ('Nearly three critical months', 28613, 28641, 'DATE'),
#  ('Roosevelt', 28670, 28679, 'PERSON'),
#  ('July 30', 28699, 28706, 'DATE'),
#  ('Canadian', 28832, 28840, 'NORP'),
#  ('Isaaor Lubin', 28891, 28903, 'PERSON'),
#  ('Labor Statistics', 28925, 28941, 'ORG'),
#  ('House', 28957, 28962, 'ORG'),
#  ('Canadian', 29018, 29026, 'NORP'),
#  ('the United States', 29069, 29086, 'GPE'),
#  ('One', 29088, 29091, 'CARDINAL'),
#  ('Canada', 29157, 29163, 'GPE'),
#  ('Industries', 29378, 29388, 'ORG'),
#  ('Canadian', 29442, 29450, 'NORP'),
#  ('American', 29455, 29463, 'NORP'),
#  ('Canadian', 29515, 29523, 'NORP'),
#  ('Canada', 29541, 29547, 'GPE'),
#  ('Canada', 29766, 29772, 'GPE'),
#  ("Mackenzie King's", 29815, 29831, 'PERSON'),
#  ('Canada', 29860, 29866, 'GPE'),
#  ('Canadian', 29991, 29999, 'NORP'),
#  ('American', 30047, 30055, 'NORP'),
#  ('the United States', 30183, 30200, 'GPE'),
#  ('Canadian', 30357, 30365, 'NORP'),
#  ('British', 30489, 30496, 'NORP'),
#  ('Russia', 30562, 30568, 'GPE'),
#  ('Russians', 30615, 30623, 'NORP'),
#  ('Germany', 30663, 30670, 'GPE'),
#  ('at least two', 30685, 30697, 'CARDINAL'),
#  ('Canada', 30786, 30792, 'GPE'),
#  ('Canada', 30877, 30883, 'GPE'),
#  ('sus j', 30910, 30915, 'ORG'),
#  ('the United States', 30984, 31001, 'GPE'),
#  ('Oprmanv', 31294, 31301, 'PERSON'),
#  ('Canada', 31447, 31453, 'GPE'),
#  ('Wash', 31471, 31475, 'GPE'),
#  ('Canadian', 31524, 31532, 'NORP'),
#  ('O. P. A.', 31585, 31593, 'PERSON'),
#  ('Ottawa', 31614, 31620, 'GPE'),
#  ('Mackenzie King', 31688, 31702, 'PERSON'),
#  ('Berlin', 31841, 31847, 'GPE'),
#  ('Canada', 31872, 31878, 'GPE'),
#  ('Nazis', 32066, 32071, 'NORP'),
#  ('Atlantic', 32173, 32181, 'LOC'),
#  ('Mackenzie King', 32251, 32265, 'PERSON'),
#  ('Canada', 32331, 32337, 'GPE'),
#  ('Marshal Goering', 32362, 32377, 'PERSON'),
#  ('Germany', 32390, 32397, 'GPE'),
#  ('five years ago', 32398, 32412, 'DATE')]

# %%
entities = set((ent.text, ent.start_char, ent.label_) 
     for ent in scydoc.ents
     if ent.label_ not in ('DATE', 'MONEY', 'CARDINAL', 'ORDINAL')
           and len(ent.text) > 3
    )
print(len(entities))
entities
# Out:
# 376
# {('"Mein Kampf  even then was available in English.', 23920, 'WORK_OF_ART'),
#  ('"My New Order', 8675, 'WORK_OF_ART'),
#  ('A Gangster Plus', 23104, 'WORK_OF_ART'),
#  ('Adolf Hitler', 12261, 'PERSON'),
#  ('America', 4469, 'GPE'),
#  ('America', 7153, 'GPE'),
#  ('America', 12840, 'GPE'),
#  ('America', 23337, 'GPE'),
#  ('America', 24005, 'GPE'),
#  ('American', 1297, 'NORP'),
#  ('American', 7196, 'NORP'),
#  ('American', 12857, 'NORP'),
#  ('American', 29455, 'NORP'),
#  ('American', 30047, 'NORP'),
#  ('American-Japanese', 1078, 'NORP'),
#  ('Americans', 9790, 'NORP'),
#  ('Aryan', 6853, 'PERSON'),
#  ('Asia', 6425, 'LOC'),
#  ('Asiatic', 3626, 'LOC'),
#  ('Asiatic', 4868, 'GPE'),
#  ('Asiatic', 7318, 'GPE'),
#  ('Atlantic', 32173, 'LOC'),
#  ('Attack Siberia', 258, 'PERSON'),
#  ('Austrian', 14606, 'NORP'),
#  ('Balkans', 9717, 'LOC'),
#  ('Bargaining Out', 27388, 'ORG'),
#  ('Berlin', 22404, 'GPE'),
#  ('Berlin', 31841, 'GPE'),
#  ('Big Business', 27435, 'ORG'),
#  ('Bolshevism', 22650, 'ORG'),
#  ('Bolshevist', 22764, 'NORP'),
#  ('Bolshevists', 23004, 'PERSON'),
#  ('Britain', 23993, 'GPE'),
#  ('Britain', 28378, 'GPE'),
#  ('British', 1285, 'NORP'),
#  ('British', 28151, 'NORP'),
#  ('British', 30489, 'NORP'),
#  ('Canada', 24442, 'GPE'),
#  ('Canada', 24723, 'GPE'),
#  ('Canada', 24911, 'GPE'),
#  ('Canada', 25077, 'GPE'),
#  ('Canada', 25417, 'GPE'),
#  ('Canada', 25720, 'GPE'),
#  ('Canada', 26883, 'GPE'),
#  ('Canada', 28180, 'GPE'),
#  ('Canada', 29157, 'GPE'),
#  ('Canada', 29541, 'GPE'),
#  ('Canada', 29766, 'GPE'),
#  ('Canada', 29860, 'GPE'),
#  ('Canada', 30786, 'GPE'),
#  ('Canada', 30877, 'GPE'),
#  ('Canada', 31447, 'GPE'),
#  ('Canada', 31872, 'GPE'),
#  ('Canada', 32331, 'GPE'),
#  ('Canadian', 24519, 'NORP'),
#  ('Canadian', 25177, 'NORP'),
#  ('Canadian', 25880, 'NORP'),
#  ('Canadian', 26357, 'NORP'),
#  ('Canadian', 26749, 'NORP'),
#  ('Canadian', 27028, 'NORP'),
#  ('Canadian', 27266, 'NORP'),
#  ('Canadian', 28391, 'NORP'),
#  ('Canadian', 28832, 'NORP'),
#  ('Canadian', 29018, 'NORP'),
#  ('Canadian', 29442, 'NORP'),
#  ('Canadian', 29515, 'NORP'),
#  ('Canadian', 29991, 'NORP'),
#  ('Canadian', 30357, 'NORP'),
#  ('Canadian', 31524, 'NORP'),
#  ('Carlyle', 10942, 'PERSON'),
#  ('Carlyle', 11871, 'PERSON'),
#  ('Charlie Chaplin', 23804, 'PERSON'),
#  ('China', 6894, 'GPE'),
#  ('Communism', 22364, 'NORP'),
#  ('Communist', 4772, 'NORP'),
#  ('Communist', 6405, 'NORP'),
#  ('Communist', 15429, 'NORP'),
#  ('Communists', 16431, 'NORP'),
#  ('Communists', 16543, 'NORP'),
#  ('Congress', 353, 'ORG'),
#  ('Constantine Brown', 276, 'PERSON'),
#  ('D. C., OCTOBER 26, 1941', 58, 'PERSON'),
#  ('David Cushman Coyle', 23270, 'PERSON'),
#  ('Dominion', 24670, 'ORG'),
#  ('Dominion', 25304, 'ORG'),
#  ('England', 9684, 'GPE'),
#  ('English', 8549, 'LANGUAGE'),
#  ('Europe', 16253, 'LOC'),
#  ('European', 12037, 'NORP'),
#  ('Evrcee', 4856, 'GPE'),
#  ('Felix M', 24353, 'PERSON'),
#  ('France', 815, 'GPE'),
#  ('France', 9694, 'GPE'),
#  ('France', 15535, 'GPE'),
#  ('Francis Hackett', 12740, 'PERSON'),
#  ('Frederick the Great', 15861, 'PERSON'),
#  ('French', 8734, 'NORP'),
#  ('Fritz Thyssen', 19166, 'PERSON'),
#  ('Fumimaro Konoye', 1989, 'PERSON'),
#  ('German', 1175, 'NORP'),
#  ('German', 1779, 'NORP'),
#  ('German', 1925, 'NORP'),
#  ('German', 3837, 'NORP'),
#  ('German', 3983, 'NORP'),
#  ('German', 10544, 'NORP'),
#  ('German', 11257, 'NORP'),
#  ('German', 11559, 'NORP'),
#  ('German', 11592, 'NORP'),
#  ('German', 11737, 'NORP'),
#  ('German', 12579, 'NORP'),
#  ('German', 14907, 'NORP'),
#  ('German', 17090, 'NORP'),
#  ('German', 22328, 'NORP'),
#  ('German', 26852, 'NORP'),
#  ('German Workers  Party', 13112, 'ORG'),
#  ('Germanic', 11218, 'PERSON'),
#  ('Germans', 943, 'NORP'),
#  ('Germans', 5343, 'NORP'),
#  ('Germans', 10068, 'NORP'),
#  ('Germans', 15178, 'NORP'),
#  ('Germans', 15845, 'NORP'),
#  ('Germany', 9009, 'GPE'),
#  ('Germany', 11302, 'GPE'),
#  ('Germany', 12896, 'GPE'),
#  ('Germany', 14948, 'GPE'),
#  ('Germany', 15255, 'GPE'),
#  ('Germany', 16213, 'GPE'),
#  ('Germany', 19573, 'GPE'),
#  ('Germany', 22749, 'GPE'),
#  ('Germany', 22866, 'GPE'),
#  ('Germany', 22961, 'GPE'),
#  ('Germany', 24455, 'GPE'),
#  ('Germany', 30663, 'GPE'),
#  ('Germany', 32390, 'GPE'),
#  ('Goddess of Misery', 18903, 'FAC'),
#  ('Hamburg', 19983, 'GPE'),
#  ('Hapsburg', 15493, 'GPE'),
#  ('Henceforward', 26974, 'PERSON'),
#  ('Hirohito', 2635, 'PERSON'),
#  ('Hitler', 3906, 'PERSON'),
#  ('Hitler', 8074, 'PERSON'),
#  ('Hitler', 8636, 'PERSON'),
#  ('Hitler', 9022, 'PERSON'),
#  ('Hitler', 9827, 'PERSON'),
#  ('Hitler', 10248, 'PERSON'),
#  ('Hitler', 10470, 'PERSON'),
#  ('Hitler', 11098, 'PERSON'),
#  ('Hitler', 11963, 'PERSON'),
#  ('Hitler', 13360, 'PERSON'),
#  ('Hitler', 13473, 'PERSON'),
#  ('Hitler', 14535, 'PERSON'),
#  ('Hitler', 15230, 'PERSON'),
#  ('Hitler', 16373, 'PERSON'),
#  ('Hitler', 17335, 'PERSON'),
#  ('Hitler', 17759, 'PERSON'),
#  ('Hitler', 19071, 'PERSON'),
#  ('Hitler', 19540, 'PERSON'),
#  ('Hitler', 19870, 'PERSON'),
#  ('Hitler', 20729, 'PERSON'),
#  ('Hitler', 21682, 'PERSON'),
#  ('Hitler', 21816, 'PERSON'),
#  ('Hitler', 22518, 'PERSON'),
#  ('Hitler', 23356, 'PERSON'),
#  ('Hitler', 23562, 'PERSON'),
#  ('Hitler', 23782, 'PERSON'),
#  ('Hitlerian', 8830, 'NORP'),
#  ('Hitlerian', 12952, 'NORP'),
#  ('Hohenzollern', 15506, 'NORP'),
#  ('House', 28957, 'ORG'),
#  ('Huey Long', 10672, 'PERSON'),
#  ('Huey Long', 17263, 'PERSON'),
#  ('Huey Long', 23654, 'PERSON'),
#  ('Huiwranc', 16880, 'PERSON'),
#  ('Industries', 29378, 'ORG'),
#  ('Inevitable', 515, 'ORG'),
#  ('Isaaor Lubin', 28891, 'PERSON'),
#  ('Italians', 773, 'NORP'),
#  ('Jack Lambert', 8306, 'PERSON'),
#  ('Jap anese', 7514, 'NORP'),
#  ('Japan', 499, 'GPE'),
#  ('Japan', 1044, 'GPE'),
#  ('Japan', 1450, 'GPE'),
#  ('Japan', 1556, 'GPE'),
#  ('Japan', 1718, 'GPE'),
#  ('Japan', 2208, 'GPE'),
#  ('Japan', 3601, 'GPE'),
#  ('Japan', 4578, 'GPE'),
#  ('Japan', 5896, 'GPE'),
#  ('Japan', 6820, 'GPE'),
#  ('Japanese', 729, 'NORP'),
#  ('Japanese', 1256, 'NORP'),
#  ('Japanese', 1829, 'NORP'),
#  ('Japanese', 2679, 'NORP'),
#  ('Japanese', 3668, 'NORP'),
#  ('Japanese', 4349, 'NORP'),
#  ('Japanese', 4665, 'NORP'),
#  ('Japanese', 5438, 'NORP'),
#  ('Japanese', 5587, 'NORP'),
#  ('Japanese', 5951, 'NORP'),
#  ('Japanese', 6279, 'NORP'),
#  ('Japanese', 6453, 'NORP'),
#  ('Japanese', 6546, 'NORP'),
#  ('Japanese', 6673, 'NORP'),
#  ('Japanese', 7108, 'NORP'),
#  ('Japanese', 8042, 'NORP'),
#  ('Jews', 15588, 'NORP'),
#  ('Jews', 21810, 'NORP'),
#  ('Joseph C. Grew', 3033, 'PERSON'),
#  ('Joseph Stalin', 583, 'PERSON'),
#  ('Junkers', 15688, 'PERSON'),
#  ('Knox s', 446, 'PERSON'),
#  ('Labor Statistics', 28925, 'ORG'),
#  ('London', 9200, 'GPE'),
#  ('M. De Sales', 24130, 'PERSON'),
#  ('M. de Sales', 9089, 'PERSON'),
#  ('M. de Sales', 13336, 'PERSON'),
#  ('Mac-', 25002, 'PERSON'),
#  ('MacDonald', 28289, 'PERSON'),
#  ('Mackenzie King', 24384, 'PERSON'),
#  ('Mackenzie King', 25804, 'PERSON'),
#  ('Mackenzie King', 26405, 'PERSON'),
#  ('Mackenzie King', 26997, 'PERSON'),
#  ('Mackenzie King', 31688, 'PERSON'),
#  ('Mackenzie King', 32251, 'PERSON'),
#  ("Mackenzie King's", 29815, 'PERSON'),
#  ('Malcolm MacDonald', 28128, 'PERSON'),
#  ('Manchukuo', 5606, 'PRODUCT'),
#  ('Manchukuo I and China', 5809, 'ORG'),
#  ('Manchukuo Siberian', 7541, 'PRODUCT'),
#  ('Marshal Goering', 32362, 'PERSON'),
#  ("Marshal Goering's", 24560, 'ORG'),
#  ('Marxian', 11006, 'NORP'),
#  ('Marxian', 11898, 'NORP'),
#  ('Mein', 9385, 'PERSON'),
#  ('Mein', 17348, 'PERSON'),
#  ('Mein', 19522, 'PERSON'),
#  ('Mein Kampf', 8613, 'PERSON'),
#  ('Mein Kampf', 8807, 'PERSON'),
#  ('Mein Kampf.', 14407, 'PERSON'),
#  ('Mein TCflmnf', 19750, 'PERSON'),
#  ('Moscow', 534, 'GPE'),
#  ('Moscow', 1378, 'GPE'),
#  ('Munich', 9057, 'GPE'),
#  ('Mv Npu', 19782, 'WORK_OF_ART'),
#  ('My New Order', 13321, 'LOC'),
#  ('Nationalists', 22681, 'NORP'),
#  ('Navy', 431, 'ORG'),
#  ('Nazi', 988, 'NORP'),
#  ('Nazi', 2138, 'NORP'),
#  ('Nazi', 16752, 'NORP'),
#  ('Nazis', 1347, 'NORP'),
#  ('Nazis', 16485, 'NORP'),
#  ('Nazis', 32066, 'NORP'),
#  ('New York', 9218, 'GPE'),
#  ('Nipponese', 235, 'NORP'),
#  ('Nipponese', 4016, 'NORP'),
#  ('Nuremberg', 19228, 'GPE'),
#  ('O. P. A.', 31585, 'PERSON'),
#  ('Oprmanv', 31294, 'PERSON'),
#  ('Ottawa', 24373, 'GPE'),
#  ('Ottawa', 31614, 'GPE'),
#  ('Pacific', 1143, 'LOC'),
#  ('Pacific', 1697, 'LOC'),
#  ('Pacific', 4303, 'LOC'),
#  ('Page B-', 24181, 'PERSON'),
#  ('Paris', 9208, 'GPE'),
#  ('Phari', 4621, 'ORG'),
#  ('Prom', 24368, 'GPE'),
#  ('Raoul de Roussy de Sales', 8752, 'PERSON'),
#  ('Raymond P. Brandt', 8392, 'PERSON'),
#  ('Reich', 1601, 'PERSON'),
#  ('Reich', 1880, 'PERSON'),
#  ('Reich', 2189, 'PERSON'),
#  ('Reich', 3891, 'PERSON'),
#  ('Reichstag', 16117, 'ORG'),
#  ('Reynal and Hitchcock', 8560, 'ORG'),
#  ('Roosevelt', 28670, 'PERSON'),
#  ('Russia', 1222, 'GPE'),
#  ('Russia', 2100, 'GPE'),
#  ('Russia', 2493, 'GPE'),
#  ('Russia', 3860, 'GPE'),
#  ('Russia', 4682, 'GPE'),
#  ('Russia', 5216, 'GPE'),
#  ('Russia', 5411, 'GPE'),
#  ('Russia', 8915, 'GPE'),
#  ('Russia', 9702, 'GPE'),
#  ('Russia', 15527, 'GPE'),
#  ('Russia', 30562, 'GPE'),
#  ('Russian', 3739, 'NORP'),
#  ('Russian', 6739, 'NORP'),
#  ('Russian', 7297, 'NORP'),
#  ('Russians', 2339, 'NORP'),
#  ('Russians', 4152, 'NORP'),
#  ('Russians', 30615, 'NORP'),
#  ('Settle Question', 5917, 'ORG'),
#  ('Siberia', 930, 'LOC'),
#  ('Siberia', 4594, 'LOC'),
#  ('Siberia', 4809, 'LOC'),
#  ('Siberia', 5462, 'LOC'),
#  ('Siberia', 5552, 'LOC'),
#  ('Siberia', 6320, 'LOC'),
#  ('Siberia', 6557, 'LOC'),
#  ('Siberia', 6769, 'LOC'),
#  ('Siberia', 7235, 'LOC'),
#  ('Siberia', 8015, 'LOC'),
#  ('Siberian', 5118, 'NORP'),
#  ('Siberian', 6952, 'NORP'),
#  ('Socialists', 16528, 'NORP'),
#  ('Soviet', 856, 'NORP'),
#  ('Soviet', 1419, 'NORP'),
#  ('Soviet', 8000, 'NORP'),
#  ('Soviet', 8180, 'NORP'),
#  ('Soviet', 8908, 'NORP'),
#  ('Soviet', 15520, 'NORP'),
#  ('Stalin', 4837, 'PERSON'),
#  ('Stalin', 8110, 'PERSON'),
#  ('Storm Troopers', 16456, 'PERSON'),
#  ('Storm Troopers', 23368, 'WORK_OF_ART'),
#  ('Stuka', 13929, 'LOC'),
#  ('The Storm Troopers', 16719, 'ORG'),
#  ('The United States', 3280, 'GPE'),
#  ('The United States', 7759, 'GPE'),
#  ('Tokio', 3794, 'PERSON'),
#  ('Tokio', 4204, 'PERSON'),
#  ('Tokio', 6931, 'PERSON'),
#  ('Tokyo', 890, 'GPE'),
#  ('Tokyo', 1610, 'GPE'),
#  ('Tokyo', 2899, 'GPE'),
#  ('Tokyo', 2966, 'GPE'),
#  ('Tom Moore', 25982, 'PERSON'),
#  ('U. S. Assistance Pledged', 7338, 'PERSON'),
#  ('United States', 2806, 'GPE'),
#  ('Versailles', 15327, 'LOC'),
#  ('Volkischer Beobachter', 18427, 'PERSON'),
#  ('Von Hindenberg', 15893, 'PERSON'),
#  ('WASHINGTON', 46, 'GPE'),
#  ('Wagner', 15882, 'PERSON'),
#  ('War With U. S.', 104, 'WORK_OF_ART'),
#  ('Wash', 31471, 'GPE'),
#  ('Washington', 322, 'GPE'),
#  ('Washington', 2884, 'GPE'),
#  ('Washington', 25617, 'GPE'),
#  ('Washington', 28474, 'GPE'),
#  ('anti-Bol', 22698, 'NORP'),
#  ('j Soon', 5696, 'PERSON'),
#  ('kenzie King', 25009, 'PERSON'),
#  ('non-Germans', 23758, 'NORP'),
#  ('ss;-', 1, 'ORG'),
#  ('sus j', 30910, 'ORG'),
#  ('the Bible of the Third Reich', 9400, 'WORK_OF_ART'),
#  ('the Far East', 3374, 'LOC'),
#  ('the House Banking and Currency Committee', 28531, 'ORG'),
#  ('the Industry  Club of Duesseldorf', 21621, 'ORG'),
#  ('the Labor Congress of Canada', 26006, 'ORG'),
#  ('the National Socialist party', 16032, 'ORG'),
#  ('the Nipponese Empire', 5674, 'GPE'),
#  ('the Nipponese Empire', 6607, 'GPE'),
#  ('the Par East', 7745, 'LOC'),
#  ('the Social Democratic', 15403, 'NORP'),
#  ('the U. S.  R.', 678, 'GPE'),
#  ('the U. S. S.', 4887, 'GPE'),
#  ('the United States', 477, 'GPE'),
#  ('the United States', 1490, 'GPE'),
#  ('the United States', 2252, 'GPE'),
#  ('the United States', 4261, 'GPE'),
#  ('the United States', 4492, 'GPE'),
#  ('the United States', 24683, 'GPE'),
#  ('the United States', 24926, 'GPE'),
#  ('the United States', 29069, 'GPE'),
#  ('the United States', 30183, 'GPE'),
#  ('the United States', 30984, 'GPE'),
#  ('the Wartime Prices and Trade Board', 27213, 'ORG'),
#  ('the Weimer Republic', 15339, 'GPE'),
#  ('the White House', 7447, 'ORG'),
#  ('the World War', 10218, 'EVENT'),
#  ('the World War', 14697, 'EVENT')}

# %%
#Remove duplicates
ents = list(entities)
print(len(ents))
for e in range(len(ents)):
    if ents[e] != False:
        for f in range(e+1, len(ents)):
            if ents[f] != False:
                if ents[e][0].lower() == ents[f][0].lower():
                #dist = distance(ents[e][0], ents[f][0])
                #if 1 >= dist or (len(ents[e][0]) > 6 and 2 == dist):
                    ents[f] = False

ents = sorted(list(filter(None, ents)), key=itemgetter(1)) #Sort by position in text.
print(len(ents))
# Out:
# 376
# 166

# %% [markdown]
# # Wikidata

# %%
wikisearchurl = "https://www.wikidata.org/w/api.php?action=wbsearchentities&language=en&limit=1&format=json&"
wikigeturl = "https://www.wikidata.org/w/api.php?action=wbgetentities&sites=enwiki&languages=en&format=json&"

# %% [markdown]
# This code searches Wikidata for each of our entities. In the end, I decided against doing it (one call to the API for each item in our list seemed excessive for this demo) but it might be worth pursuing.
#
# As a compromise, I could search for items that aren't found in my next attempt below.

# %%
"""
cnt = 0
mapdata = []
for search in ents:
    results = get(wikiurltemp + urlencode({'search': search[0]})).json()
    print(search)
    try: 
        print(results)
        res = results['search'][0]
        print(res)
        cnt += 1
    except:
        print('no results')
    print('-------------------------------')
    sleep(.05)
cnt
"""
# Out:
# "\ncnt = 0\nmapdata = []\nfor search in ents:\n    results = get(wikiurltemp + urlencode({'search': search[0]})).json()\n    print(search)\n    try: \n        print(results)\n        res = results['search'][0]\n        print(res)\n        cnt += 1\n        if search[3] == 'GPE':\n    except:\n        print('no results')\n    print('-------------------------------')\n    sleep(.05)\ncnt\n"

# %% [markdown]
# This code retrieves Wikidata entries by article name. It misses some items that searching might retrieve, but this API allows us to request 50 titles per call.

# %%
outp = {}
while ents:
    srch = '|'.join(e[0] for e in ents[:50])
    del(ents[:50])
    results = get(wikigeturl + urlencode({'titles': srch})).json()
    outp.update({k: v for k, v in results['entities'].items() if k[0] != '-'})

# %%
EntityData = namedtuple('EntityData', ('name', 'description', 'url', 'lat', 'long'))
entity_data = []

for idx, ent in outp.items():
    entity_data.append(EntityData(py_.get(ent, 'labels.en.value'),
                                  py_.get(ent, 'descriptions.en.value'),
                                  f'https://www.wikidata.org/wiki/{idx}',
                                  py_.get(ent, 'claims.P625.0.mainsnak.datavalue.value.longitude', False),
                                  py_.get(ent, 'claims.P625.0.mainsnak.datavalue.value.latitude', False)))

# %% [markdown]
# # Folium

# %% [markdown]
# Finally, as an example of what the Wikidata input is good for, we can map the locations of entities we have geographic data for.

# %%
import os
import folium
from folium.plugins import MarkerCluster


m = folium.Map()

marker_cluster = MarkerCluster().add_to(m)

for ent in entity_data:
    if ent.lat and ent.long:
        #print(ent)
        folium.Marker(
            location=[ent.long, ent.lat],
            popup=f'<h3>{ent.name}</h3>{ent.description}',
            icon=folium.Icon(color='blue'),
        ).add_to(marker_cluster)
    
#m.save(os.path.join('1000_MarkerCluster0.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Closing
#
# * Chronicling America API: https://chroniclingamerica.loc.gov/about/api/
# * Wikidata API:  https://www.mediawiki.org/wiki/API:Web_APIs_hub
# * [XML (Text Creation Partnership - Eighteenth Century Collections Online)](https://github.com/Text-Creation-Partnership/ECCO-TCP/blob/master/ecco_all/ecco_unfinished/XML/ECCO_unedited.xml/K134436.000.xml) [[Description](https://textcreationpartnership.org/tcp-texts/ecco-tcp-eighteenth-century-collections-online/)]
#
# I ended up using two of these--I considered doing a similar analysis using the ECCO data, but thought I'd have more luck finding named entities from newspapers in Wikidata.
